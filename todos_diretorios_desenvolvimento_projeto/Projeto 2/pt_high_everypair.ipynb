# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn
import statsmodels.api as sm
from scipy.stats import zscore
from statsmodels import regression
from statsmodels.tsa.stattools import coint

import time

# %%
data = pd.read_excel('/home/daniel/Desktop/Projetos/mql_python/Relatório 1/dados_relatorio.xlsx')
# tickers = ['close IBOV', 'close ABEV3', 'close B3SA3', 'close BBAS3', 'close BBDC3', 'close BBDC4', 'close BEEF3', 'close BRAP4', 'close BRFS3', 'close BRKM5', 'close BRML3', 'close BTOW3', 'close CCRO3', 'close CIEL3', 'close CMIG4', 'close COGN3', 'close CPFE3', 'close CSAN3', 'close CSNA3', 'close CYRE3', 'close ECOR3', 'close ELET3', 'close ELET6', 'close EMBR3', 'close ENBR3', 'close EQTL3', 'close FLRY3', 'close GGBR4', 'close GOAU4', 'close GOLL4', 'close HGTX3', 'close HYPE3', 'close IGTA3', 'close ITSA4', 'close ITUB4', 'close JBSS3', 'close LAME4', 'close LREN3', 'close MGLU3', 'close MRFG3', 'close MRVE3', 'close MULT3', 'close NTCO3', 'close PETR3', 'close PETR4', 'close QUAL3', 'close RADL3', 'close RAIL3', 'close RENT3', 'close SANB11', 'close SBSP3', 'close SULA11', 'close SUZB3', 'close TIMP3', 'close TOTS3', 'close UGPA3', 'close USIM5', 'close VALE3', 'close VIVT4', 'close WEGE3', 'close YDUQ3']
# dados = data[tickers]

# %%
tickers = ['close BBAS3', 'close ITSA4']
dados = data[tickers][:]

# %%
dados
# Out:
#       close BBAS3  close ITSA4
# 0           14.71         3.82
# 1           14.64         3.82
# 2           14.48         3.81
# 3           14.12         3.83
# 4           14.23         3.85
# ...           ...          ...
# 1970        50.45        13.37
# 1971        51.98        13.46
# 1972        52.57        13.70
# 1973        52.34        13.64
# 1974        52.19        13.60
#
# [1975 rows x 2 columns]

# %%
momentaneo = dados.copy()

# %%
# mom = np.log(momentaneo).pct_change()[1:]
mom = momentaneo.pct_change()[1:]
dados = dados[1:]
mom
# Out:
#       close BBAS3  close ITSA4
# 1       -0.004759     0.000000
# 2       -0.010929    -0.002618
# 3       -0.024862     0.005249
# 4        0.007790     0.005222
# 5        0.021082     0.015584
# ...           ...          ...
# 1970    -0.001978    -0.008895
# 1971     0.030327     0.006731
# 1972     0.011351     0.017831
# 1973    -0.004375    -0.004380
# 1974    -0.002866    -0.002933
#
# [1974 rows x 2 columns]

# %%
dados
# Out:
#       close BBAS3  close ITSA4
# 1           14.64         3.82
# 2           14.48         3.81
# 3           14.12         3.83
# 4           14.23         3.85
# 5           14.53         3.91
# ...           ...          ...
# 1970        50.45        13.37
# 1971        51.98        13.46
# 1972        52.57        13.70
# 1973        52.34        13.64
# 1974        52.19        13.60
#
# [1974 rows x 2 columns]

# %%
def calcula_zscore_spread(s1,s2,t1,t2):
    s1 = sm.add_constant(s1)
    results = sm.OLS(s2,s1).fit()
    s1 = s1[t1]
    b = results.params[t1]
    spread = s2 - (b*s1)
    zs = zscore(spread)[-1]
    return zs

def cria_variaveis(par):
    dic[par] = {}
    dic[par]['Posicionado'] = False
    dic[par]['Saldo Financeiro'] = 100000
    dic[par]['Numero Operacoes'] = 0
    dic[par]['Duracao Operacao'] = []
    dic[par]['Volume'] = 0
    dic[par]['diferenca dias'] = 0
    dic[par]['Razao s1/s2'] = 0
    
    dic[par]['Entrada'] = 0
    dic[par]['Saída'] = 0

    return dic[par]

# %%
l_zs = []
l_resultado = []

dic = {}
start = time.process_time()
c = 0
tickers = mom.columns.to_list()
for index in range(90,len(mom)): #todas as linhas dos dados
    for i in range(len(tickers)-1): #todas os tickers 
        for j in range(i+1, len(tickers)): #todas as possibilidades de pares
            t1,t2 = tickers[i], tickers[j]
            s1,s2 = mom[t1][c:index],mom[t2][c:index]
            preco_s1 = dados[t1][dados.index == index].values[0]
            preco_s2 = dados[t2][dados.index == index].values[0]
            
            #cria dados sobre os pares de trade
            par = (t1+' x '+t2)
            print(par)
            if not par in dic:
                cria_variaveis(par)

#             if coint(s1,s2)[1] < 0.01: #checa se sao cointegrados
            zs = calcula_zscore_spread(s1,s2,t1,t2)

            #condicao para se posicionar
            if zs >= 1.1 and dic[par]['Posicionado'] == False:
                carteira = dic[par]['Saldo Financeiro']
                l_zs.append(zs)

                dic[par]['Razao s1/s2'] = preco_s1/preco_s2 
                dic[par]['Volume'] = carteira/2/preco_s1 #volume de acordo com a carteira
                v, q = dic[par]['Volume'], dic[par]['Razao s1/s2'] #razao para posicao ficar igual 

                carteira -= v*preco_s1 #comprou Stock1
                print(f'Comprou: {(v*preco_s1):.2f}, Vendeu:  {(v*preco_s2*q):.2f}')
                carteira += v*preco_s2*q #vendeu Stock2 (recebe o dinheiro)
                
                dic[par]['Entrada'] = -v*preco_s1 + v*preco_s2*q
                dic[par]['Saldo Financeiro'] = carteira
                dic[par]['Posicionado'] = True
                dic[par]['diferenca dias'] = index

            #condicao para encerrar posicao    
            elif (zs > -.08 and zs < .08) and dic[par]['Posicionado'] == True:
                v, q = dic[par]['Volume'], dic[par]['Razao s1/s2'] #razao para posicao ficar igual 
                
                dic[par]['Saldo Financeiro'] += v*preco_s1 #vnedeu Stock1
                print(f'Vendeu:  {(v*preco_s1):.2f}, Comprou: {(v*preco_s2*q):.2f}')

                dic[par]['Saldo Financeiro'] -= v*q*preco_s2 #comprou Stock2
    
                
                print(f'Resultado: {(dic[par]["Entrada"] + v*preco_s1 - v*q*preco_s2):.2f}')
                print(f"{dic[par]['Saldo Financeiro']}\n")
                dic[par]['Posicionado'] = False
                dic[par]['Numero Operacoes'] += 1
                dic[par]['Duracao Operacao'].append(index - dic[par]['diferenca dias'])
                dic[par]['diferenca dias'] = 0
    c+=1
    
print(time.process_time() - start)
# Out:
# close BBAS3 x close ITSA4
# Comprou: 50000.00, Vendeu:  50000.00
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49096.62, Comprou: 48253.97
# Resultado: 842.65
# 100842.65389842764
#
# close BBAS3 x close ITSA4
# Comprou: 50421.33, Vendeu:  50421.33
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  48025.74, Comprou: 49012.04
# Resultado: -986.29
# 99856.36223836603
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 49928.18, Vendeu:  49928.18
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  58899.97, Comprou: 56951.72
# Resultado: 1948.25
# 101804.61041550999
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50902.31, Vendeu:  50902.31
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49144.72, Comprou: 49550.92
# Resultado: -406.19
# 101398.41613380419
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50699.21, Vendeu:  50699.21
# close BBAS3 x close ITSA4
# Vendeu:  51680.48, Comprou: 51311.89
# Resultado: 368.60
# 101767.01187708369
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50883.51, Vendeu:  50883.51
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  55070.36, Comprou: 52936.44
# Resultado: 2133.92
# 103900.93134583204
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51950.47, Vendeu:  51950.47
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  52382.61, Comprou: 53306.87
# Resultado: -924.26
# 102976.67117332366
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51488.34, Vendeu:  51488.34
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  45423.96, Comprou: 47902.08
# Resultado: -2478.13
# 100498.54539817902
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50249.27, Vendeu:  50249.27
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56530.43, Comprou: 51014.49
# Resultado: 5515.94
# 106014.48713481767
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 53007.24, Vendeu:  53007.24
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  47604.69, Comprou: 53678.22
# Resultado: -6073.53
# 99940.95679536942
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 49970.48, Vendeu:  49970.48
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  52494.85, Comprou: 50349.04
# Resultado: 2145.81
# 102086.76852796151
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51043.38, Vendeu:  51043.38
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51916.42, Comprou: 51168.49
# Resultado: 747.93
# 102834.69613236169
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51417.35, Vendeu:  51417.35
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  47993.56, Comprou: 49132.13
# Resultado: -1138.57
# 101696.12825990818
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50848.06, Vendeu:  50848.06
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51367.25, Comprou: 48797.74
# Resultado: 2569.51
# 104265.64233906096
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52132.82, Vendeu:  52132.82
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  53386.01, Comprou: 53390.72
# Resultado: -4.70
# 104260.93866629098
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52130.47, Vendeu:  52130.47
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  53775.61, Comprou: 53288.92
# Resultado: 486.69
# 104747.62680865171
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52373.81, Vendeu:  52373.81
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  48104.06, Comprou: 51183.50
# Resultado: -3079.44
# 101668.18571299092
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50834.09, Vendeu:  50834.09
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49299.92, Comprou: 49407.63
# Resultado: -107.70
# 101560.48381241754
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50780.24, Vendeu:  50780.24
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49499.24, Comprou: 51054.73
# Resultado: -1555.49
# 100004.99379689258
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50002.50, Vendeu:  50002.50
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  54705.87, Comprou: 53648.51
# Resultado: 1057.35
# 101062.3486866939
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50531.17, Vendeu:  50531.17
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51656.01, Comprou: 50646.28
# Resultado: 1009.73
# 102072.0812909976
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51036.04, Vendeu:  51036.04
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51590.78, Comprou: 51947.40
# Resultado: -356.62
# 101715.46299456166
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50857.73, Vendeu:  50857.73
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51158.34, Comprou: 49166.23
# Resultado: 1992.11
# 103707.5717369761
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51853.79, Vendeu:  51853.79
# close BBAS3 x close ITSA4
# Vendeu:  51880.09, Comprou: 51853.79
# Resultado: 26.31
# 103733.88010119146
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51866.94, Vendeu:  51866.94
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50863.38, Comprou: 54614.13
# Resultado: -3750.75
# 99983.13005415993
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 49991.57, Vendeu:  49991.57
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  46534.44, Comprou: 48699.54
# Resultado: -2165.10
# 97818.03044500813
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48909.02, Vendeu:  48909.02
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  57519.94, Comprou: 53668.28
# Resultado: 3851.66
# 101669.69508985989
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50834.85, Vendeu:  50834.85
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50224.30, Comprou: 50524.88
# Resultado: -300.58
# 101369.11458966587
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50684.56, Vendeu:  50684.56
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49225.37, Comprou: 53933.57
# Resultado: -4708.20
# 96660.91337420384
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48330.46, Vendeu:  48330.46
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50208.16, Comprou: 47966.39
# Resultado: 2241.77
# 98902.68816474002
#
# close BBAS3 x close ITSA4
# Comprou: 49451.34, Vendeu:  49451.34
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  49286.78, Comprou: 48706.31
# Resultado: 580.47
# 99483.15428972489
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 49741.58, Vendeu:  49741.58
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  45052.06, Comprou: 45298.81
# Resultado: -246.75
# 99236.40195405605
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 49618.20, Vendeu:  49618.20
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  36782.71, Comprou: 41156.18
# Resultado: -4373.48
# 94862.9267259299
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 47431.46, Vendeu:  47431.46
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50773.71, Comprou: 47760.09
# Resultado: 3013.62
# 97876.54931201701
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48938.27, Vendeu:  48938.27
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  53488.99, Comprou: 51356.40
# Resultado: 2132.59
# 100009.14059049329
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50004.57, Vendeu:  50004.57
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  46497.24, Comprou: 48132.15
# Resultado: -1634.92
# 98374.22383108508
#
# close BBAS3 x close ITSA4
# Comprou: 49187.11, Vendeu:  49187.11
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  41890.91, Comprou: 43685.20
# Resultado: -1794.29
# 96579.93101061488
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48289.97, Vendeu:  48289.97
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  48911.92, Comprou: 49412.99
# Resultado: -501.07
# 96078.85843471633
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48039.43, Vendeu:  48039.43
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  55648.36, Comprou: 50882.58
# Resultado: 4765.78
# 100844.63827064737
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50422.32, Vendeu:  50422.32
# close BBAS3 x close ITSA4
# Vendeu:  50958.44, Comprou: 50708.81
# Resultado: 249.63
# 101094.27029985936
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50547.14, Vendeu:  50547.14
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  47585.85, Comprou: 51652.54
# Resultado: -4066.69
# 97027.57767370774
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 48513.79, Vendeu:  48513.79
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  60282.81, Comprou: 55611.00
# Resultado: 4671.82
# 101699.39398261727
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 50849.70, Vendeu:  50849.70
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  52258.63, Comprou: 51365.07
# Resultado: 893.57
# 102592.95910181405
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51296.48, Vendeu:  51296.48
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56752.99, Comprou: 52454.21
# Resultado: 4298.78
# 106891.73749885973
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 53445.87, Vendeu:  53445.87
# close BBAS3 x close ITSA4
# Vendeu:  50998.45, Comprou: 52285.80
# Resultado: -1287.36
# 105604.37952315705
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52802.19, Vendeu:  52802.19
# close BBAS3 x close ITSA4
# Vendeu:  55661.84, Comprou: 54057.39
# Resultado: 1604.45
# 107208.82642340346
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 53604.41, Vendeu:  53604.41
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  57321.84, Comprou: 59049.34
# Resultado: -1727.50
# 105481.32412456596
#
# close BBAS3 x close ITSA4
# Comprou: 52740.66, Vendeu:  52740.66
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  52345.99, Comprou: 52412.06
# Resultado: -66.07
# 105415.25423421299
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52707.63, Vendeu:  52707.63
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  53193.50, Comprou: 53966.32
# Resultado: -772.82
# 104642.43877519504
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52321.22, Vendeu:  52321.22
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50394.48, Comprou: 49734.72
# Resultado: 659.76
# 105302.20194423194
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52651.10, Vendeu:  52651.10
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51531.25, Comprou: 52723.82
# Resultado: -1192.57
# 104109.6275387611
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52054.81, Vendeu:  52054.81
# close BBAS3 x close ITSA4
# Vendeu:  51277.57, Comprou: 51656.84
# Resultado: -379.27
# 103730.35732218168
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51865.18, Vendeu:  51865.18
# close BBAS3 x close ITSA4
# Vendeu:  52403.65, Comprou: 52190.35
# Resultado: 213.29
# 103943.65117468796
#
# close BBAS3 x close ITSA4
# Comprou: 51971.83, Vendeu:  51971.83
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  48360.30, Comprou: 50290.15
# Resultado: -1929.85
# 102013.79912127036
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 51006.90, Vendeu:  51006.90
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56174.62, Comprou: 52425.95
# Resultado: 3748.67
# 105762.46985751219
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52881.23, Vendeu:  52881.23
# close BBAS3 x close ITSA4
# Vendeu:  52818.75, Comprou: 52881.23
# Resultado: -62.48
# 105699.98710651328
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52849.99, Vendeu:  52849.99
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  54373.34, Comprou: 54606.57
# Resultado: -233.23
# 105466.7594155118
#
# close BBAS3 x close ITSA4
# Comprou: 52733.38, Vendeu:  52733.38
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  55603.36, Comprou: 55133.66
# Resultado: 469.70
# 105936.45805017464
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52968.23, Vendeu:  52968.23
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56009.47, Comprou: 55952.35
# Resultado: 57.11
# 105993.57050144504
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52996.79, Vendeu:  52996.79
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51639.20, Comprou: 49972.15
# Resultado: 1667.04
# 107660.61436736805
#
# close BBAS3 x close ITSA4
# Comprou: 53830.31, Vendeu:  53830.31
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  53091.67, Comprou: 55023.42
# Resultado: -1931.75
# 105728.86915369818
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52864.43, Vendeu:  52864.43
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  50891.61, Comprou: 51589.78
# Resultado: -698.18
# 105030.69305656324
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52515.35, Vendeu:  52515.35
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56062.92, Comprou: 55576.47
# Resultado: 486.44
# 105517.13456731752
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52758.57, Vendeu:  52758.57
# close BBAS3 x close ITSA4
# Vendeu:  52758.57, Comprou: 52821.15
# Resultado: -62.58
# 105454.55026448992
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 52727.28, Vendeu:  52727.28
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  65242.50, Comprou: 62113.89
# Resultado: 3128.61
# 108583.16515527462
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 54291.58, Vendeu:  54291.58
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  46980.53, Comprou: 49123.39
# Resultado: -2142.86
# 106440.30643990514
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 53220.15, Vendeu:  53220.15
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  51656.29, Comprou: 51618.74
# Resultado: 37.55
# 106477.85401133061
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 53238.93, Vendeu:  53238.93
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  48417.02, Comprou: 45213.53
# Resultado: 3203.49
# 109681.34464490962
#
# close BBAS3 x close ITSA4
# Comprou: 54840.67, Vendeu:  54840.67
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  60074.18, Comprou: 61604.58
# Resultado: -1530.40
# 108150.94625788293
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 54075.47, Vendeu:  54075.47
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  69043.15, Comprou: 60273.60
# Resultado: 8769.55
# 116920.49715681262
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 58460.25, Vendeu:  58460.25
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  66020.59, Comprou: 63518.18
# Resultado: 2502.42
# 119422.91336747775
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 59711.46, Vendeu:  59711.46
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  57849.98, Comprou: 56922.73
# Resultado: 927.25
# 120350.16160800951
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 60175.08, Vendeu:  60175.08
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  60982.89, Comprou: 61413.03
# Resultado: -430.14
# 119920.02080145795
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 59960.01, Vendeu:  59960.01
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  63824.59, Comprou: 61501.40
# Resultado: 2323.20
# 122243.21681814262
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 61121.61, Vendeu:  61121.61
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  64672.40, Comprou: 61905.89
# Resultado: 2766.51
# 125009.72628007771
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 62504.86, Vendeu:  62504.86
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  61462.30, Comprou: 64376.27
# Resultado: -2913.97
# 122095.7577746854
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 61047.88, Vendeu:  61047.88
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  57828.76, Comprou: 59241.41
# Resultado: -1412.66
# 120683.10107940355
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 60341.55, Vendeu:  60341.55
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  62187.39, Comprou: 57286.96
# Resultado: 4900.43
# 125583.52639839973
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 62791.76, Vendeu:  62791.76
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  64681.69, Comprou: 65169.81
# Resultado: -488.12
# 125095.40353692196
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 62547.70, Vendeu:  62547.70
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  62127.09, Comprou: 62441.69
# Resultado: -314.60
# 124780.80308995041
#
# close BBAS3 x close ITSA4
# Comprou: 62390.40, Vendeu:  62390.40
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  54875.83, Comprou: 64906.56
# Resultado: -10030.73
# 114750.07512973255
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 57375.04, Vendeu:  57375.04
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  56753.93, Comprou: 58834.50
# Resultado: -2080.57
# 112669.504700494
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 56334.75, Vendeu:  56334.75
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Vendeu:  59207.79, Comprou: 59550.00
# Resultado: -342.21
# 112327.29112591053
#
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# Comprou: 56163.65, Vendeu:  56163.65
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# close BBAS3 x close ITSA4
# 6.384903870999999

# %%
for k,v in dic.items():
    print(k,v['Saldo Financeiro'])
    print('')
# Out:
# close BBAS3 x close ITSA4 112327.29112591053

# %%
len(l_zs)
# Out:
# 84

# %%
l_resultado
# Out:
# []

# %%
contador = 0
for i in range(len(tickers)):
    for j in range(i+1, len(tickers)-1):
        if (coint(mom[tickers[i]],mom[tickers[j]])[1]) > .1:
            print(f'{tickers[i]} and {tickers[j]} nao cointegrated')

# %%
mom.columns.to_list()
# Out:
# ['close BBAS3', 'close ITSA4']

# %%
plt.plot(l_zs)

# %%
pd.DataFrame(l_zs)
# Out:
#            0
# 0   1.573583
# 1   1.763268
# 2   3.924053
# 3   2.036785
# 4   3.346847
# ..       ...
# 79  1.299467
# 80  1.693265
# 81  1.165313
# 82  1.666682
# 83  1.403168
#
# [84 rows x 1 columns]

# %%
dic = {}

class Pair_trading():
    def __init__(self, dados, t1, t2, index, posicao_financeira):
        self.t1, self.t2 = t1, t2
        self.par = (t1+' x '+t2)
        self.posicao_financeira = posicao_financeira
        self.index = index
        self.dados = dados 
        
        dic[self.par] = {}

        
    def realiza_operacao(self):
        #apenas financeiro
        self.posicao_financeira -= (dados[t1][dados.index == self.index].values[0]) #comprou
        dic[self.par]['Posicao Financeira'] = self.posicao_financeira
        
        return self.posicao_financeira

# %%
banana = Pair_trading(dados,t1,t2,1047,0)
banana.realiza_operacao()
# Out:
# -16.83

# %%
dic
# Out:
# {'close BBAS3 x close ITSA4': {'Posicao Financeira': -16.83}}

# %%
t1 = 'close IBOV'

# %%
banana1 = Pair_trading(dados,t1,t2,1053,0)

# %%
banana1.realiza_operacao()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close IBOV'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-597bd7e3d395> in <module>
# ----> 1 banana1.realiza_operacao()
#
# <ipython-input-17-e363234be4cc> in realiza_operacao(self)
#      14     def realiza_operacao(self):
#      15         #apenas financeiro
# ---> 16         self.posicao_financeira -= (dados[t1][dados.index == self.index].values[0]) #comprou
#      17         dic[self.par]['Posicao Financeira'] = self.posicao_financeira
#      18
#
# /usr/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close IBOV'

# %%
dic={}

# %%
dic['potato'] = 10

# %%
if not (dic['potato']):
    print('oi')

# %%
#Quero saber qual é o par que foi operado, a quantidade de operacões, a duração, e o resultado.

# %%
mom
