# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn
import statsmodels.api as sm
from scipy.stats import zscore
from statsmodels import regression
from statsmodels.tsa.stattools import coint

# %%
class Pair_trading():
    def __init__(self, data_var,data_preco, par, valor_inicial):
        self.financeiro = valor_inicial
        self.posicionado = 0 #comeca sem nenhuma operação aberta
        self.lista_resultado_operacoes = []
        self.lista_evolucao_carteira = []
        self.lista_dias_carregando = []
        self.lista_rentabilidade_operacao = []
        self.contador_dias = 0 
        self.perm_pct_acumulado = 1
        #guarda tickers das acoes
        self.t1 = par[0] 
        self.t2 = par[1]
        self.volume_operacao = 0

        self.dados_var = data_var
        self.dados_preco = data_preco

    def calcula_zscore_spread(self,stock1,stock2):
        stock1 = sm.add_constant(stock1)
        results = sm.OLS(stock2,stock1).fit()
        stock1 = stock1[self.t1]
        b = results.params[self.t1]
        spread = stock2 - (b*stock1)
        zs = zscore(spread)[-1]
        return zs
        
    def condicoes_operar(self,zs, gatilho_high, preco_s1, preco_s2, index):
        if zs >= gatilho_high and self.posicionado == 0:
            #parametros para iniciar operacao
            self.posicionado = 1 #entrou em uma operacao            
            self.volume = (self.financeiro/2)//preco_s1
            self.razao = preco_s1/preco_s2
            self.contador_dias = index
            #guarda dados de quantas ações está comprado/vendido
            self.qtd_s1 =  self.volume
            self.qtd_s2 =  self.volume*self.razao
            #calcula valor total da compra e venda (idealmente devem ser iguais)
            valor_operado_s1 =  preco_s1*self.qtd_s1 #vende  s1 (credita caixa)
            valor_operado_s2 = -preco_s2*self.qtd_s2 #compra s2 (debita caixa) 
#             print(f'v1  R${valor_operado_s1:.2f} | v2 R${valor_operado_s2:.2f}')
#             print(f'C1  R${preco_s1:.2f} | D2 R${(preco_s2*self.razao):.2f}')
            self.financeiro += valor_operado_s1 + valor_operado_s2

        elif zs <= 0.08 and self.posicionado == 1:
            #calcula preço das açoes que estão em carteira
            valor_operado_s1 = -self.qtd_s1*preco_s1 #compra s1 (debita  caixa) 
            valor_operado_s2 =  self.qtd_s2*preco_s2 #vende  s2 (credita caixa)
#             print(f'v1 R${valor_operado_s1:.2f} | v2  R${valor_operado_s2:.2f}')
#             print(f'D1  R${preco_s1:.2f} | C2 R${(preco_s2*self.razao):.2f}')
            resultado_trade = valor_operado_s1 + valor_operado_s2 
#             print(f'resu: R${resultado_trade:.2f}\n')
            self.financeiro += resultado_trade 
            #zera quantidades de ações sendo operadas
            self.qtd_s1 -= self.qtd_s1
            self.qtd_s2 -= self.qtd_s2
            #guarda dados para acompanhamento ao longo do tempo
            pct_change_trade = resultado_trade/(self.financeiro-resultado_trade)
            self.perm_pct_acumulado = self.perm_pct_acumulado*(1+pct_change_trade)
            self.lista_rentabilidade_operacao.append(pct_change_trade*100)
            self.lista_evolucao_carteira.append(self.financeiro)
            self.lista_dias_carregando.append(index-self.contador_dias)
            self.lista_resultado_operacoes.append(resultado_trade)
            #zera parametros para próximas operações 
            self.posicionado = 0
            self.razao = 0
            self.volume = 0
            self.contador_dias = 0
        
    def opera(self):
        period = 45
        c = 0
        s1 = self.dados_var[self.t1]
        s2 = self.dados_var[self.t2]
        for index in range(period, len(self.dados_var)):
            j1 = (s1[c:index]) #seleciona a acao 1 com uma janela com *period* dias 
            j2 = (s2[c:index])

            preco_s1 = self.dados_preco[self.t1][self.dados_var.index == index].values[0]
            preco_s2 = self.dados_preco[self.t2][self.dados_var.index == index].values[0]
            
            zs = self.calcula_zscore_spread(stock1=j1,stock2=j2)
            self.condicoes_operar(zs=zs, gatilho_high = 1.1, preco_s1=preco_s1, preco_s2=preco_s2, index=index)
            c += 1

# %%
data = pd.read_excel('/home/daniel/Desktop/Projetos/mql_python/Relatório 1/dados_relatorio.xlsx')[1:]
data = data.drop(['time','close IBOV','close AZUL4','close BBSE3','close BPAC11','close BRDT3','close CRFB3','close CVCB3','close GNDI3','close HAPV3','close IRBR3','close KLBN11','close TAEE11','close VVAR3'],axis=1)
data_var = data.pct_change()[1:600]
data_preco = data[1:600]

# %%
# aa = pd.DataFrame(np.sum(data_var.isnull()))
# for i in aa.index:
#     print(i,aa[aa.index==i].values[0][0])
#     print('\n')

# %%
ltick = data_var.columns.to_list()
ltick_usados = []
for i in range(len(ltick)):
    for j in range(i+1,len(ltick)):
        ltick_usados.append([ltick[i],ltick[j]])

# %%
doc = {}
ll_par_usado = []
for i in ltick_usados:
    a = (i[0]+' x '+i[1])
    ll_par_usado.append(a)
    doc[a] = Pair_trading(data_var=data_var, data_preco=data_preco, par=i, valor_inicial=1000)
    doc[a].opera()
# Out:
# <ipython-input-68-bacfedbbc313>:32: RuntimeWarning: invalid value encountered in double_scalars
#   self.volume = (self.financeiro/2)//preco_s1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-5d54aa8b481d> in <module>
#       5     ll_par_usado.append(a)
#       6     doc[a] = Pair_trading(data_var=data_var, data_preco=data_preco, par=i, valor_inicial=1000)
# ----> 7     doc[a].opera()
#
# <ipython-input-68-bacfedbbc313> in opera(self)
#      80             preco_s2 = self.dados_preco[self.t2][self.dados_var.index == index].values[0]
#      81
# ---> 82             zs = self.calcula_zscore_spread(stock1=j1,stock2=j2)
#      83             self.condicoes_operar(zs=zs, gatilho_high = 1.1, preco_s1=preco_s1, preco_s2=preco_s2, index=index)
#      84             c += 1
#
# <ipython-input-68-bacfedbbc313> in calcula_zscore_spread(self, stock1, stock2)
#      21         results = sm.OLS(stock2,stock1).fit()
#      22         stock1 = stock1[self.t1]
# ---> 23         b = results.params[self.t1]
#      24         spread = stock2 - (b*stock1)
#      25         zs = zscore(spread)[-1]
#
# /usr/lib/python3.8/site-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      40             obj = data.wrap_output(obj, how[0], *how[1:])
#      41         elif how:
# ---> 42             obj = data.wrap_output(obj, how=how)
#      43
#      44         return obj
#
# /usr/lib/python3.8/site-packages/statsmodels/base/data.py in wrap_output(self, obj, how, names)
#     437     def wrap_output(self, obj, how='columns', names=None):
#     438         if how == 'columns':
# --> 439             return self.attach_columns(obj)
#     440         elif how == 'rows':
#     441             return self.attach_rows(obj)
#
# /usr/lib/python3.8/site-packages/statsmodels/base/data.py in attach_columns(self, result)
#     557         # if it needs a squeeze, the bug is elsewhere
#     558         if result.ndim <= 1:
# --> 559             return Series(result, index=self.param_names)
#     560         else:  # for e.g., confidence intervals
#     561             return DataFrame(result, index=self.param_names)
#
# /usr/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# --> 305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
#     307                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     406
#     407     # extract ndarray or ExtensionArray, ensure we have no PandasArray
# --> 408     data = extract_array(data, extract_numpy=True)
#     409
#     410     # GH#846
#
# /usr/lib/python3.8/site-packages/pandas/core/construction.py in extract_array(obj, extract_numpy)
#     380         obj = obj.array
#     381
# --> 382     if extract_numpy and isinstance(obj, ABCPandasArray):
#     383         obj = obj.to_numpy()
#     384
#
# /usr/lib/python3.8/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
# ---> 12         return getattr(inst, attr, "_typ") in comp
#      13
#      14     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
lista_rentabilidades = []
for i in ll_par_usado:
    lista_rentabilidades.append(doc[i].perm_pct_acumulado)
    
lista_rentabilidades = sorted(lista_rentabilidades)

# %%
for i in lista_rentabilidades:
    for k,v in doc.items():
        if v.perm_pct_acumulado == i:
            print(f'{k} {i:.2f}')
# Out:
# close ABEV3 x close CCRO3 2.28
# close B3SA3 x close ECOR3 2.33
# close ABEV3 x close ECOR3 2.39
# close B3SA3 x close UGPA3 2.40
# close B3SA3 x close MULT3 2.41
# close ABEV3 x close EGIE3 2.43
# close B3SA3 x close EGIE3 2.46
# close ABEV3 x close FLRY3 2.48
# close ABEV3 x close CPFE3 2.50
# close ABEV3 x close BBDC4 2.57
# close B3SA3 x close FLRY3 2.57
# close B3SA3 x close ITSA4 2.59
# close B3SA3 x close RENT3 2.61
# close B3SA3 x close SANB11 2.65
# close B3SA3 x close ITUB4 2.69
# close ABEV3 x close ITSA4 2.77
# close B3SA3 x close SBSP3 2.82
# close ABEV3 x close CSAN3 2.83
# close ABEV3 x close CIEL3 2.83
# close ABEV3 x close ITUB4 2.84
# close B3SA3 x close NTCO3 2.85
# close ABEV3 x close BRFS3 2.86
# close B3SA3 x close ENBR3 2.87
# close B3SA3 x close LAME4 2.89
# close B3SA3 x close HGTX3 2.89
# close ABEV3 x close IGTA3 2.90
# close B3SA3 x close LREN3 2.94
# close ABEV3 x close HGTX3 2.94
# close ABEV3 x close LAME4 2.96
# close ABEV3 x close BBDC3 2.96
# close B3SA3 x close HYPE3 2.97
# close ABEV3 x close EQTL3 3.04
# close ABEV3 x close BRAP4 3.07
# close ABEV3 x close ENBR3 3.08
# close ABEV3 x close CMIG4 3.14
# close ABEV3 x close LREN3 3.14
# close B3SA3 x close IGTA3 3.16
# close ABEV3 x close HYPE3 3.19
# close ABEV3 x close BRML3 3.21
# close B3SA3 x close RADL3 3.21
# close B3SA3 x close EQTL3 3.27
# close B3SA3 x close TOTS3 3.29
# close B3SA3 x close TIMP3 3.32
# close B3SA3 x close SULA11 3.37
# close ABEV3 x close CYRE3 3.45
# close ABEV3 x close EMBR3 3.47
# close B3SA3 x close GGBR4 3.58
# close B3SA3 x close ELET6 3.58
# close ABEV3 x close BBAS3 3.61
# close B3SA3 x close EMBR3 3.62
# close B3SA3 x close PETR4 3.73
# close B3SA3 x close GOAU4 3.76
# close ABEV3 x close B3SA3 3.83
# close ABEV3 x close GGBR4 3.86
# close ABEV3 x close BEEF3 3.91
# close ABEV3 x close ELET6 3.94
# close ABEV3 x close GOAU4 3.96
# close ABEV3 x close BRKM5 4.00
# close ABEV3 x close COGN3 4.14
# close B3SA3 x close ELET3 4.45
# close ABEV3 x close JBSS3 5.27
# close ABEV3 x close CSNA3 5.54
# close ABEV3 x close ELET3 5.74
# close ABEV3 x close BTOW3 14.39
# close ABEV3 x close MULT3 2.05
# close B3SA3 x close CPFE3 2.23
# close B3SA3 x close CMIG4 2.29
# close B3SA3 x close CIEL3 2.37
# close ABEV3 x close VIVT4 2.39
# close ABEV3 x close UGPA3 2.55
# close B3SA3 x close CCRO3 2.59
# close B3SA3 x close BRFS3 2.64
# close B3SA3 x close CSAN3 2.66
# close B3SA3 x close BBDC4 2.66
# close ABEV3 x close NTCO3 2.70
# close B3SA3 x close BBDC3 2.78
# close ABEV3 x close WEGE3 2.79
# close ABEV3 x close SULA11 2.83
# close ABEV3 x close SANB11 2.90
# close B3SA3 x close BRAP4 2.93
# close ABEV3 x close TOTS3 2.94
# close B3SA3 x close BRML3 3.00
# close ABEV3 x close RENT3 3.00
# close ABEV3 x close SBSP3 3.22
# close B3SA3 x close CYRE3 3.24
# close B3SA3 x close BBAS3 3.24
# close ABEV3 x close QUAL3 3.26
# close ABEV3 x close VALE3 3.31
# close ABEV3 x close YDUQ3 3.34
# close B3SA3 x close BEEF3 3.39
# close ABEV3 x close RADL3 3.45
# close ABEV3 x close TIMP3 3.77
# close ABEV3 x close RAIL3 3.93
# close ABEV3 x close PETR4 3.98
# close ABEV3 x close SUZB3 4.04
# close B3SA3 x close BRKM5 4.18
# close ABEV3 x close PETR3 4.24
# close B3SA3 x close COGN3 4.51
# close B3SA3 x close CSNA3 5.24
# close ABEV3 x close USIM5 6.64
# close ABEV3 x close MRVE3 7.37
# close ABEV3 x close MGLU3 7.46
# close ABEV3 x close MRFG3 7.70
# close ABEV3 x close GOLL4 9.52
# close B3SA3 x close BTOW3 17.38
# close BBAS3 x close BBDC4 2.07
# close BBAS3 x close ITSA4 2.14
# close BBAS3 x close ITUB4 2.15
# close B3SA3 x close VIVT4 2.25
# close BBAS3 x close EGIE3 2.27
# close BBAS3 x close CPFE3 2.31
# close BBAS3 x close ECOR3 2.36
# close BBAS3 x close BRFS3 2.62
# close BBAS3 x close FLRY3 2.72
# close B3SA3 x close WEGE3 2.73
# close BBAS3 x close BBDC3 2.77
# close BBAS3 x close LAME4 2.77
# close BBAS3 x close BRAP4 2.79
# close BBAS3 x close CCRO3 2.83
# close BBAS3 x close CSAN3 2.91
# close BBAS3 x close CMIG4 2.95
# close BBAS3 x close CIEL3 2.98
# close BBAS3 x close IGTA3 3.02
# close BBAS3 x close HGTX3 3.05
# close BBAS3 x close EQTL3 3.10
# close B3SA3 x close VALE3 3.10
# close BBAS3 x close BRML3 3.13
# close BBAS3 x close GGBR4 3.17
# close BBAS3 x close ENBR3 3.22
# close BBAS3 x close CYRE3 3.25
# close BBAS3 x close ELET6 3.33
# close B3SA3 x close YDUQ3 3.36
# close BBAS3 x close BEEF3 3.45
# close BBAS3 x close EMBR3 3.66
# close B3SA3 x close QUAL3 3.67
# close BBAS3 x close GOAU4 3.72
# close B3SA3 x close PETR3 3.74
# close BBAS3 x close HYPE3 3.75
# close B3SA3 x close SUZB3 3.78
# close BBAS3 x close BRKM5 3.91
# close BBAS3 x close ELET3 4.14
# close B3SA3 x close RAIL3 4.41
# close BBAS3 x close CSNA3 4.64
# close BBAS3 x close COGN3 4.81
# close BBAS3 x close JBSS3 5.25
# close B3SA3 x close JBSS3 5.42
# close B3SA3 x close MRVE3 6.36
# close B3SA3 x close USIM5 6.94
# close B3SA3 x close MRFG3 7.39
# close B3SA3 x close MGLU3 7.59
# close BBAS3 x close GOLL4 8.80
# close B3SA3 x close GOLL4 8.99
# close BBAS3 x close BTOW3 16.36
# close BBDC3 x close BBDC4 1.48
# close BBDC4 x close ITSA4 1.79
# close BBDC4 x close ITUB4 1.87
# close BBDC3 x close ITSA4 2.03
# close BBDC3 x close ITUB4 2.06
# close BBDC4 x close VIVT4 2.07
# close BBDC3 x close EGIE3 2.11
# close BBDC3 x close VIVT4 2.13
# close BBAS3 x close MULT3 2.14
# close BBDC4 x close ECOR3 2.16
# close BBDC4 x close MULT3 2.19
# close BBDC4 x close CPFE3 2.25
# close BBDC4 x close EGIE3 2.26
# close BBDC3 x close MULT3 2.28
# close BBDC3 x close CPFE3 2.29
# close BBDC4 x close SANB11 2.30
# close BBAS3 x close VIVT4 2.34
# close BBDC3 x close FLRY3 2.35
# close BBDC3 x close ECOR3 2.38
# close BBDC4 x close FLRY3 2.38
# close BBDC4 x close UGPA3 2.40
# close BBDC4 x close LAME4 2.40
# close BBDC4 x close SBSP3 2.41
# close BEEF3 x close CPFE3 2.41
# close BBDC3 x close LAME4 2.43
# close BBDC3 x close CIEL3 2.45
# close BBDC4 x close CIEL3 2.46
# close BBDC3 x close UGPA3 2.47
# close BBDC4 x close BRAP4 2.49
# close BBAS3 x close RENT3 2.49
# close BBDC3 x close NTCO3 2.50
# close BBDC4 x close CCRO3 2.52
# close BBDC3 x close SANB11 2.52
# close BBDC3 x close BRFS3 2.53
# close BBAS3 x close UGPA3 2.53
# close BEEF3 x close ECOR3 2.53
# close BEEF3 x close CCRO3 2.54
# close BBAS3 x close SANB11 2.61
# close BBDC3 x close CCRO3 2.62
# close BBDC3 x close WEGE3 2.63
# close BBDC3 x close SBSP3 2.63
# close BBDC3 x close IGTA3 2.66
# close BBDC4 x close CSAN3 2.66
# close BEEF3 x close BRFS3 2.69
# close BBDC3 x close BRAP4 2.70
# close BBDC3 x close LREN3 2.70
# close BBAS3 x close SBSP3 2.71
# close BBDC4 x close RENT3 2.72
# close BBAS3 x close WEGE3 2.73
# close BEEF3 x close EGIE3 2.74
# close BBDC3 x close RENT3 2.74
# close BBDC3 x close CSAN3 2.76
# close BBDC3 x close BRML3 2.76
# close BBDC3 x close VALE3 2.76
# close BBDC3 x close CMIG4 2.77
# close BEEF3 x close CSAN3 2.77
# close BBDC4 x close BRFS3 2.79
# close BBAS3 x close LREN3 2.79
# close BEEF3 x close CIEL3 2.79
# close BEEF3 x close CMIG4 2.80
# close BBDC4 x close NTCO3 2.81
# close BBDC4 x close VALE3 2.82
# close BBDC4 x close IGTA3 2.84
# close BBDC4 x close WEGE3 2.88
# close BBAS3 x close NTCO3 2.89
# close BBDC4 x close BRML3 2.91
# close BBDC3 x close EQTL3 2.92
# close BBDC4 x close CMIG4 2.92
# close BBDC4 x close LREN3 2.93
# close BBDC4 x close TOTS3 2.94
# close BBDC3 x close QUAL3 2.94
# close BBDC3 x close HGTX3 2.95
# close BBDC4 x close EQTL3 2.96
# close BBDC3 x close TOTS3 2.97
# close BBDC4 x close ENBR3 3.00
# close BBDC4 x close QUAL3 3.01
# close BBDC3 x close CYRE3 3.04
# close BBDC4 x close CYRE3 3.08
# close BBDC3 x close ENBR3 3.09
# close BBDC3 x close PETR4 3.12
# close BBAS3 x close PETR4 3.14
# close BBDC3 x close GOAU4 3.16
# close BBDC4 x close HGTX3 3.17
# close BBAS3 x close QUAL3 3.18
# close BBAS3 x close SULA11 3.21
# close BBDC4 x close PETR4 3.21
# close BBAS3 x close TOTS3 3.22
# close BEEF3 x close BRAP4 3.22
# close BBAS3 x close YDUQ3 3.22
# close BBDC3 x close ELET6 3.22
# close BBAS3 x close PETR3 3.23
# close BBDC4 x close EMBR3 3.24
# close BBDC4 x close SULA11 3.25
# close BBDC3 x close HYPE3 3.26
# close BBDC3 x close YDUQ3 3.27
# close BBDC3 x close EMBR3 3.29
# close BBDC4 x close PETR3 3.31
# close BEEF3 x close BRML3 3.34
# close BBDC4 x close TIMP3 3.34
# close BBDC3 x close GGBR4 3.35
# close BBAS3 x close RADL3 3.38
# close BBDC3 x close BRKM5 3.38
# close BBDC4 x close ELET6 3.39
# close BBDC4 x close GGBR4 3.40
# close BBDC4 x close RADL3 3.42
# close BBAS3 x close VALE3 3.44
# close BBAS3 x close RAIL3 3.46
# close BBDC4 x close HYPE3 3.46
# close BBDC4 x close GOAU4 3.46
# close BEEF3 x close COGN3 3.46
# close BBDC4 x close YDUQ3 3.50
# close BBAS3 x close TIMP3 3.56
# close BEEF3 x close ELET6 3.68
# close BEEF3 x close CYRE3 3.69
# close BBDC4 x close RAIL3 3.78
# close BBAS3 x close SUZB3 3.80
# close BBDC4 x close BEEF3 3.88
# close BBDC4 x close BRKM5 3.92
# close BBDC3 x close BEEF3 3.97
# close BBDC3 x close COGN3 4.11
# close BBDC3 x close ELET3 4.12
# close BBDC4 x close SUZB3 4.13
# close BBDC4 x close COGN3 4.13
# close BEEF3 x close BRKM5 4.24
# close BBDC4 x close ELET3 4.52
# close BBDC4 x close CSNA3 4.55
# close BBDC3 x close CSNA3 4.63
# close BEEF3 x close CSNA3 5.35
# close BBAS3 x close USIM5 5.71
# close BEEF3 x close ELET3 5.72
# close BBAS3 x close MRVE3 5.93
# close BBDC4 x close MRVE3 6.13
# close BBDC4 x close MRFG3 6.82
# close BBDC4 x close USIM5 6.89
# close BBAS3 x close MRFG3 6.91
# close BBDC4 x close MGLU3 7.08
# close BBAS3 x close MGLU3 7.63
# close BBDC3 x close PETR3 3.16
# close BBDC3 x close RADL3 3.33
# close BBDC3 x close TIMP3 3.41
# close BBDC3 x close RAIL3 3.52
# close BBDC3 x close SULA11 3.55
# close BBDC3 x close SUZB3 3.95
# close BBDC3 x close JBSS3 5.30
# close BBDC3 x close USIM5 5.52
# close BBDC3 x close MRVE3 6.04
# close BBDC3 x close MGLU3 6.54
# close BBDC3 x close MRFG3 6.91
# close BBDC3 x close GOLL4 8.43
# close BBDC4 x close BTOW3 15.93
# close BEEF3 x close VIVT4 1.99
# close BRAP4 x close EGIE3 2.32
# close BEEF3 x close UGPA3 2.38
# close BRAP4 x close ECOR3 2.41
# close BRAP4 x close CMIG4 2.45
# close BRAP4 x close CPFE3 2.46
# close BEEF3 x close FLRY3 2.48
# close BRAP4 x close MULT3 2.49
# close BRAP4 x close CCRO3 2.53
# close BEEF3 x close MULT3 2.56
# close BEEF3 x close RENT3 2.57
# close BEEF3 x close EQTL3 2.58
# close BEEF3 x close WEGE3 2.60
# close BEEF3 x close SBSP3 2.62
# close BRAP4 x close NTCO3 2.63
# close BRAP4 x close ITUB4 2.65
# close BRAP4 x close ITSA4 2.68
# close BRAP4 x close FLRY3 2.69
# close BRAP4 x close ENBR3 2.71
# close BRAP4 x close LAME4 2.74
# close BEEF3 x close IGTA3 2.78
# close BEEF3 x close TOTS3 2.80
# close BRAP4 x close BRFS3 2.85
# close BRAP4 x close GOAU4 2.90
# close BEEF3 x close VALE3 2.93
# close BRAP4 x close HYPE3 2.93
# close BEEF3 x close NTCO3 2.93
# close BEEF3 x close LAME4 2.94
# close BRAP4 x close HGTX3 3.01
# close BEEF3 x close ENBR3 3.02
# close BRAP4 x close CIEL3 3.06
# close BEEF3 x close EMBR3 3.10
# close BEEF3 x close HGTX3 2.89
# close BEEF3 x close ITUB4 3.06
# close BEEF3 x close QUAL3 3.08
# close BRAP4 x close PETR3 3.12
# close BRAP4 x close GGBR4 3.13
# close BRAP4 x close EQTL3 3.13
# close BRAP4 x close CSAN3 3.15
# close BEEF3 x close TIMP3 3.17
# close BEEF3 x close SULA11 3.19
# close BEEF3 x close SANB11 3.21
# close BRAP4 x close PETR4 3.22
# close BEEF3 x close HYPE3 3.24
# close BEEF3 x close RADL3 3.25
# close BEEF3 x close ITSA4 3.28
# close BEEF3 x close LREN3 3.29
# close BRAP4 x close EMBR3 3.31
# close BRAP4 x close IGTA3 3.35
# close BRAP4 x close BRML3 3.39
# close BRAP4 x close LREN3 3.39
# close BEEF3 x close GGBR4 3.42
# close BEEF3 x close YDUQ3 3.46
# close BRAP4 x close ELET6 3.47
# close BRAP4 x close CYRE3 3.50
# close BEEF3 x close GOAU4 3.53
# close BRAP4 x close CSNA3 3.54
# close BRAP4 x close BRKM5 3.57
# close BEEF3 x close PETR4 4.01
# close BEEF3 x close SUZB3 4.09
# close BRAP4 x close ELET3 4.16
# close BEEF3 x close RAIL3 4.24
# close BEEF3 x close PETR3 4.40
# close BRAP4 x close COGN3 4.80
# close BEEF3 x close JBSS3 5.46
# close BRAP4 x close JBSS3 6.00
# close BEEF3 x close MRFG3 6.20
# close BEEF3 x close USIM5 6.67
# close BEEF3 x close MRVE3 7.03
# close BRAP4 x close MRVE3 7.18
# close BEEF3 x close MGLU3 8.33
# close BRAP4 x close MRFG3 8.70
# close BRAP4 x close BTOW3 17.16
# close BRAP4 x close VALE3 1.64
# close BRAP4 x close VIVT4 2.04
# close BRFS3 x close CPFE3 2.18
# close BRFS3 x close CCRO3 2.38
# close BRFS3 x close EGIE3 2.42
# close BRFS3 x close CIEL3 2.46
# close BRAP4 x close UGPA3 2.61
# close BRFS3 x close FLRY3 2.61
# close BRFS3 x close ECOR3 2.69
# close BRFS3 x close CSAN3 2.77
# close BRAP4 x close TOTS3 2.77
# close BRFS3 x close EQTL3 2.82
# close BRFS3 x close ENBR3 2.90
# close BRAP4 x close RENT3 2.97
# close BRFS3 x close CMIG4 2.98
# close BRAP4 x close SBSP3 3.01
# close BRFS3 x close BRML3 3.04
# close BRAP4 x close SANB11 3.08
# close BRFS3 x close GGBR4 3.12
# close BRFS3 x close CYRE3 3.13
# close BRAP4 x close WEGE3 3.15
# close BRAP4 x close RADL3 3.20
# close BRFS3 x close EMBR3 3.27
# close BRAP4 x close TIMP3 3.35
# close BRFS3 x close ELET6 3.41
# close BRAP4 x close QUAL3 3.43
# close BRAP4 x close YDUQ3 3.49
# close BRFS3 x close GOAU4 3.53
# close BRAP4 x close SULA11 3.55
# close BRAP4 x close RAIL3 3.65
# close BRFS3 x close BRKM5 4.13
# close BRAP4 x close SUZB3 4.27
# close BRFS3 x close COGN3 4.42
# close BRFS3 x close ELET3 4.83
# close BRFS3 x close CSNA3 4.94
# close BRAP4 x close USIM5 5.94
# close BRFS3 x close GOLL4 7.99
# close BRFS3 x close BTOW3 13.20
# close BRKM5 x close EGIE3 2.10
# close BRKM5 x close ITUB4 2.36
# close BRKM5 x close ITSA4 2.46
# close BRKM5 x close ECOR3 2.52
# close BRKM5 x close RENT3 2.56
# close BRKM5 x close MULT3 2.59
# close BRKM5 x close SANB11 2.62
# close BRKM5 x close FLRY3 2.68
# close BRKM5 x close LAME4 2.72
# close BRKM5 x close EMBR3 2.86
# close BRKM5 x close SBSP3 2.92
# close BRKM5 x close IGTA3 2.95
# close BRKM5 x close HYPE3 2.98
# close BRKM5 x close ENBR3 3.00
# close BRKM5 x close ELET6 3.10
# close BRKM5 x close NTCO3 3.12
# close BRKM5 x close QUAL3 3.15
# close BRKM5 x close EQTL3 3.16
# close BRKM5 x close TIMP3 3.17
# close BRKM5 x close PETR4 3.28
# close BRKM5 x close HGTX3 3.30
# close BRKM5 x close GOAU4 3.30
# close BRKM5 x close LREN3 3.32
# close BRKM5 x close CYRE3 3.41
# close BRKM5 x close RADL3 3.50
# close BRKM5 x close GGBR4 3.51
# close BRKM5 x close SULA11 3.55
# close BRKM5 x close TOTS3 3.70
# close BRKM5 x close PETR3 3.79
# close BRKM5 x close SUZB3 3.81
# close BRKM5 x close CSNA3 3.90
# close BRKM5 x close ELET3 4.16
# close BRML3 x close MULT3 2.08
# close BRKM5 x close VIVT4 2.27
# close BRML3 x close EGIE3 2.39
# close BRML3 x close ECOR3 2.45
# close BRML3 x close CCRO3 2.52
# close BRML3 x close FLRY3 2.57
# close BRML3 x close CPFE3 2.58
# close BRKM5 x close UGPA3 2.59
# close BRML3 x close ITUB4 2.59
# close BRML3 x close IGTA3 2.63
# close BRML3 x close ITSA4 2.68
# close BRML3 x close LAME4 2.68
# close BRKM5 x close WEGE3 2.69
# close BRML3 x close LREN3 2.76
# close BRML3 x close CIEL3 2.78
# close BRML3 x close HGTX3 2.81
# close BRML3 x close ENBR3 2.82
# close BRML3 x close HYPE3 2.85
# close BRML3 x close EQTL3 2.94
# close BRML3 x close CSAN3 2.95
# close BRML3 x close CMIG4 3.16
# close BRKM5 x close VALE3 3.20
# close BRML3 x close CYRE3 3.51
# close BRML3 x close EMBR3 3.62
# close BRML3 x close GOAU4 3.94
# close BRML3 x close ELET6 4.01
# close BRKM5 x close RAIL3 4.03
# close BRKM5 x close YDUQ3 4.06
# close BRML3 x close GGBR4 4.16
# close BRML3 x close ELET3 4.21
# close BRML3 x close COGN3 4.28
# close BRKM5 x close USIM5 5.15
# close BRKM5 x close JBSS3 5.28
# close BRML3 x close CSNA3 5.74
# close BRML3 x close MRFG3 6.45
# close BRML3 x close MGLU3 6.69
# close BRML3 x close MRVE3 7.01
# close BRML3 x close BTOW3 19.23
# close BTOW3 x close CCRO3 1.98
# close BRML3 x close VIVT4 2.20
# close BTOW3 x close CPFE3 2.22
# close BTOW3 x close EGIE3 2.26
# close BTOW3 x close FLRY3 2.31
# close BRML3 x close RENT3 2.34
# close BTOW3 x close ELET6 2.35
# close BTOW3 x close CMIG4 2.48
# close BTOW3 x close CYRE3 2.57
# close BRML3 x close UGPA3 2.62
# close BTOW3 x close ECOR3 2.62
# close BTOW3 x close CSAN3 2.71
# close BTOW3 x close ELET3 2.74
# close BRML3 x close NTCO3 2.79
# close BRML3 x close WEGE3 2.80
# close BTOW3 x close GOAU4 2.85
# close BTOW3 x close ENBR3 2.92
# close BTOW3 x close GGBR4 3.05
# close BRML3 x close SANB11 3.14
# close BRML3 x close YDUQ3 3.16
# close BRML3 x close TOTS3 3.17
# close BRML3 x close SULA11 3.19
# close BRML3 x close SBSP3 3.22
# close BTOW3 x close EQTL3 3.25
# close BRML3 x close RADL3 3.30
# close BTOW3 x close CIEL3 3.46
# close BRML3 x close VALE3 3.52
# close BTOW3 x close EMBR3 3.76
# close BTOW3 x close CSNA3 3.77
# close BRML3 x close QUAL3 3.78
# close BRML3 x close PETR4 3.83
# close BRML3 x close RAIL3 3.83
# close BRML3 x close TIMP3 3.85
# close BRML3 x close PETR3 4.10
# close BRML3 x close SUZB3 4.26
# close BTOW3 x close COGN3 4.34
# close BTOW3 x close GOLL4 6.86
# close BRML3 x close USIM5 7.11
# close CCRO3 x close CMIG4 1.07
# close BTOW3 x close LAME4 1.89
# close BTOW3 x close ITSA4 1.96
# close BTOW3 x close MULT3 1.96
# close BTOW3 x close VIVT4 1.97
# close BTOW3 x close UGPA3 2.05
# close BRFS3 x close VIVT4 2.09
# close BTOW3 x close NTCO3 2.25
# close BTOW3 x close RADL3 2.27
# close BTOW3 x close HYPE3 2.29
# close BTOW3 x close LREN3 2.30
# close BRFS3 x close MULT3 2.32
# close BRFS3 x close UGPA3 2.32
# close BRKM5 x close CPFE3 2.33
# close BTOW3 x close HGTX3 2.37
# close BTOW3 x close RENT3 2.39
# close BTOW3 x close WEGE3 2.40
# close BTOW3 x close SANB11 2.43
# close BTOW3 x close VALE3 2.44
# close BTOW3 x close ITUB4 2.46
# close BRFS3 x close RENT3 2.53
# close BRKM5 x close CCRO3 2.53
# close CCRO3 x close CIEL3 2.57
# close BRFS3 x close ITUB4 2.58
# close BTOW3 x close IGTA3 2.63
# close BRKM5 x close CMIG4 2.64
# close BRFS3 x close SANB11 2.65
# close BTOW3 x close SBSP3 2.65
# close BRKM5 x close CSAN3 2.67
# close BTOW3 x close SULA11 2.67
# close BRFS3 x close ITSA4 2.69
# close BRFS3 x close WEGE3 2.71
# close BRFS3 x close NTCO3 2.75
# close BRFS3 x close HYPE3 2.78
# close BRFS3 x close LAME4 2.79
# close BRFS3 x close IGTA3 2.82
# close BRKM5 x close CIEL3 2.83
# close BRFS3 x close QUAL3 2.90
# close BRFS3 x close SBSP3 2.94
# close BRFS3 x close LREN3 2.95
# close BRFS3 x close HGTX3 2.97
# close BTOW3 x close TIMP3 3.05
# close BRFS3 x close SULA11 3.14
# close BRKM5 x close BRML3 3.15
# close BTOW3 x close TOTS3 3.22
# close BRFS3 x close TOTS3 3.23
# close BRFS3 x close RAIL3 3.24
# close BTOW3 x close YDUQ3 3.25
# close BTOW3 x close PETR4 3.26
# close BTOW3 x close RAIL3 3.30
# close BRFS3 x close TIMP3 3.34
# close BTOW3 x close QUAL3 3.45
# close BRFS3 x close YDUQ3 3.52
# close BRFS3 x close RADL3 3.57
# close BRFS3 x close VALE3 3.57
# close BTOW3 x close PETR3 3.62
# close BRFS3 x close SUZB3 3.67
# close BRFS3 x close PETR4 3.70
# close BRFS3 x close PETR3 4.11
# close BRKM5 x close COGN3 4.16
# close BTOW3 x close SUZB3 4.40
# close BTOW3 x close MRVE3 4.65
# close BTOW3 x close JBSS3 4.65
# close BTOW3 x close USIM5 4.82
# close BBDC4 x close JBSS3 5.01
# close BRFS3 x close MRVE3 5.44
# close BRFS3 x close JBSS3 5.47
# close BRML3 x close JBSS3 5.84
# close BRKM5 x close MRVE3 5.95
# close BTOW3 x close MRFG3 6.00
# close BRFS3 x close MRFG3 6.02
# close BTOW3 x close MGLU3 6.49
# close BRFS3 x close USIM5 6.70
# close BRKM5 x close MGLU3 6.80
# close BRAP4 x close MGLU3 6.90
# close BRKM5 x close GOLL4 7.48
# close BRFS3 x close MGLU3 7.50
# close BRKM5 x close MRFG3 7.83
# close BBDC4 x close GOLL4 7.98
# close BEEF3 x close GOLL4 8.96
# close BRML3 x close GOLL4 9.42
# close BRAP4 x close GOLL4 9.76
# close BEEF3 x close BTOW3 15.37
# close BRKM5 x close BTOW3 16.08
# close BBDC3 x close BTOW3 16.85

# %%
len(lista_rentabilidades)
# Out:
# 618
