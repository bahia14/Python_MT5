# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn
import statsmodels.api as sm
from scipy.stats import zscore
from statsmodels import regression
from statsmodels.tsa.stattools import coint

# %%
class Pair_trading():
    def __init__(self, data_var,data_preco, par, valor_inicial):
        self.financeiro = valor_inicial
        self.posicionado = 0 #comeca sem nenhuma operação aberta
        self.lista_resultado_operacoes = []
        self.lista_evolucao_carteira = []
        #guarda tickers das acoes
        self.t1 = par[0] 
        self.t2 = par[1]
        
        self.volume_operacao = 0
        
        self.dados_var = data_var
        self.dados_preco = data_preco

    def calcula_zscore_spread(self,stock1,stock2):
        stock1 = sm.add_constant(stock1)
        results = sm.OLS(stock2,stock1).fit()
        stock1 = stock1[self.t1]
        b = results.params[self.t1]
        spread = stock2 - (b*stock1)
        zs = zscore(spread)[-1]
        return zs
        
    def condicoes_operar(self,zs, gatilho_high, preco_s1, preco_s2):
        if zs >= gatilho_high and self.posicionado == 0:
            self.volume = (self.financeiro/2)//preco_s1
            self.razao = preco_s1/preco_s2
            
            self.posicionado = 1 #entrou em uma operacao
            
            resultado_entrada = preco_s1*self.volume - preco_s2*self.razao*self.volume
            self.financeiro += resultado_entrada
#             print(f'entra: {resultado_entrada:.2f}')
#             self.financeiro += preco_s1*self.volume #ponta short (recebe dinheiro)
#             self.financeiro -= preco_s2*self.razao*self.volume #ponta long (debito financeiro)
#             print(f'entrou: p1: {(preco_s1*self.volume):.2f} | p2: {(preco_s2*self.razao*self.volume):.2f}')

        elif zs <= 0.08 and self.posicionado == 1:
            self.posicionado = 0
            
#             self.financeiro -= preco_s1*self.volume #encerra ponta short (debito financeiro)
#             self.financeiro += preco_s2*self.razao*self.volume #encerra ponta long (recebe dinheiro)
            resultado_saida = -preco_s1*self.volume + preco_s2*self.razao*self.volume
            self.financeiro += resultado_saida
        
            self.lista_resultado_operacoes.append(resultado_saida)
            self.lista_evolucao_carteira.append(self.financeiro)
            print(f'saida: {resultado_saida:.2f}')
#             print(f'saiu  : p1: {(preco_s1*self.volume):.2f} | p2: {(preco_s2*self.razao*self.volume):.2f}\n')

            self.razao = 0
            self.volume = 0
        
        
    def opera(self):
        period = 45
        c = 0
        s1 = self.dados_var[self.t1]
        s2 = self.dados_var[self.t2]
        for index in range(period, len(self.dados_var)):
            j1 = (s1[c:index]) #seleciona a acao 1 com uma janela com *period* dias 
            j2 = (s2[c:index])

            preco_s1 = self.dados_preco[self.t1][self.dados_var.index == index].values[0]
            preco_s2 = self.dados_preco[self.t2][self.dados_var.index == index].values[0]
            
#             print(f'p1: {preco_s1:.2f} p2: {preco_s2:.2f}')
            zs = self.calcula_zscore_spread(stock1=j1,stock2=j2)
            self.condicoes_operar(zs=zs, gatilho_high = 1.1, preco_s1=preco_s1, preco_s2=preco_s2)
            c += 1

# %%
data = pd.read_excel('/home/daniel/Desktop/Projetos/mql_python/Relatório 1/dados_relatorio.xlsx')[1:]

# saida: 10.34
# saida: 9.31
# saida: 14.08
# saida: 20.74
# saida: 14.31
# saida: 9.95
# saida: 14.29
# saida: 20.80
# saida: 29.18
# saida: 32.77
# saida: 11.96
# saida: 14.64
# saida: 4.89
# saida: 14.79
# saida: 19.79
# saida: 15.24
# saida: 11.15
# saida: 44.05
# saida: 23.84
# saida: 15.64
# saida: 60.57
# saida: 40.05
# saida: 44.62
# saida: 39.99
# saida: 22.20
# saida: 135.07
# saida: 16.17
# saida: 79.00
# saida: 40.25
# saida: 32.23
# saida: 54.73
# saida: 27.58
# saida: 86.70
# saida: 45.17
# saida: 43.82
# saida: 72.89
# saida: 37.81
# saida: 41.90
# saida: 24.85
# saida: 79.10
# saida: 19.90
# saida: 49.05
# saida: 47.32
# saida: 21.99
# saida: 32.71
# saida: 39.21
# saida: 23.58
# saida: 60.51
# saida: 37.66
# saida: 31.43
# saida: 38.80
# saida: 78.64
# saida: 68.33
# saida: 23.70
# saida: 25.86
# saida: 66.13
# saida: 34.55
# saida: 84.31
# saida: 29.40
# saida: 29.79
# saida: 39.85
# saida: 17.52
# saida: 48.75
# saida: 44.43
# saida: 26.28
# saida: 26.20
# saida: 19.50
# saida: 57.93
# saida: 18.77
# saida: 13.97
# saida: 18.52
# saida: 45.56
# saida: 20.48
# saida: 15.11
# saida: 34.09
# saida: 45.58
# saida: 13.37
# saida: 17.65
# saida: 42.16
# saida: 32.26
# saida: 52.10
# saida: 18.28
# saida: 57.84
# saida: 46.70
# saida: 34.37
# saida: 20.49
# saida: 24.57
# saida: 29.67
# saida: 60.45
# saida: 27.03
# saida: 62.25
# saida: 62.08
# saida: 38.92
# saida: 31.81
# saida: 42.37
# saida: 58.36
# saida: 45.81
# saida: 50.06
# saida: 49.85
# saida: 28.11
# saida: 157.83
# saida: 51.79
# saida: 75.32
# saida: 67.17
# saida: 119.73
# saida: 134.72
# saida: 37.17
# saida: 47.06
# saida: 85.85
# saida: 51.48
# saida: 76.51
# saida: 67.91
# saida: 35.80
# saida: 39.69
# saida: 48.36
# saida: 34.70
# saida: 68.67
# saida: 73.12
# saida: 53.60
# saida: 128.40
# saida: 30.79
# saida: 199.70
# saida: 64.11
# saida: 85.32
# saida: 42.32
# saida: 52.93
# saida: 112.25

# %%
for k,v in dic.items():
    print(k)
# Out:
# close ITSA4 x close VALE3
# close BBAS3 x close BBSE3
# close ITUB4 x close BBDC4

# %%
plt.figure(figsize=[17,5])
l1 = dic['close ITSA4 x close VALE3'].lista_resultado_operacoes
plt.plot(l1)

# %%
l1_series = pd.DataFrame(l1)
l1_series.describe()
# Out:
#                   0
# count    202.000000
# mean    1488.938380
# std     2282.634670
# min      -56.303774
# 25%       55.131910
# 50%      511.024098
# 75%     1949.776462
# max    16057.567250

# %%
for k,v in dic.items():
    print(v.financeiro)
# Out:
# 301765.55267675023
# 19208.274420269227
# 7931.808160369164
