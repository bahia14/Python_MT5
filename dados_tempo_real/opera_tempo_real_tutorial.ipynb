# %%
import MetaTrader5 as mt5
from datetime import datetime
import pytz
import pandas as pd

# %%
# display data on the MetaTrader 5 package
print("MetaTrader5 package author: ",mt5.__author__)
print("MetaTrader5 package version: ",mt5.__version__)
# Out:
# MetaTrader5 package author:  MetaQuotes Software Corp.
# MetaTrader5 package version:  5.0.33

# %%
if not mt5.initialize():
    print("initialize() failed, error code =",mt5.last_error())
    quit()

# %%
print(mt5.account_info())
# Out:
# AccountInfo(login=1000349177, trade_mode=2, leverage=1, limit_orders=0, margin_so_mode=1, trade_allowed=True, trade_expert=True, margin_mode=0, currency_digits=2, fifo_close=False, balance=0.0, credit=0.0, profit=0.0, equity=0.0, margin=0.0, margin_free=0.0, margin_level=0.0, margin_so_call=0.0, margin_so_so=0.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='DANIEL COSTA DELATTRE', server='CLEAR-PRD', currency='BRL', company='CLEAR CTVM S.A.')

# %%
account_info_dict = mt5.account_info()._asdict()   
# convert the dictionary into DataFrame and print
df=pd.DataFrame(list(account_info_dict.items()),columns=['property','value'])
print("account_info() as dataframe:")
print(df)
# Out:
# account_info() as dataframe:
#               property                  value
# 0                login             1000349177
# 1           trade_mode                      2
# 2             leverage                      1
# 3         limit_orders                      0
# 4       margin_so_mode                      1
# 5        trade_allowed                   True
# 6         trade_expert                   True
# 7          margin_mode                      0
# 8      currency_digits                      2
# 9           fifo_close                  False
# 10             balance                      0
# 11              credit                      0
# 12              profit                      0
# 13              equity                      0
# 14              margin                      0
# 15         margin_free                      0
# 16        margin_level                      0
# 17      margin_so_call                      0
# 18        margin_so_so                      0
# 19      margin_initial                      0
# 20  margin_maintenance                      0
# 21              assets                      0
# 22         liabilities                      0
# 23  commission_blocked                      0
# 24                name  DANIEL COSTA DELATTRE
# 25              server              CLEAR-PRD
# 26            currency                    BRL
# 27             company        CLEAR CTVM S.A.

# %%
mt5.symbols_total()
# Out:
# 17651

# %%
# import the 'pandas' module for displaying data obtained in the tabular form
pd.set_option('display.max_columns', 500) # number of columns to be displayed
pd.set_option('display.width', 1500)      # max table width to display
# import pytz module for working with time zone

# set time zone to UTC
timezone = pytz.timezone("Etc/UTC")
# create 'datetime' objects in UTC time zone to avoid the implementation of a local time zone offset
utc_from = datetime(2020, 6, 1, tzinfo=timezone)
utc_to = datetime(2020, 8, 3, tzinfo=timezone)
# request AUDUSD ticks within 11.01.2020 - 11.01.2020
ticks = mt5.copy_ticks_range("IBOV", utc_from, utc_to, mt5.COPY_TICKS_ALL)#COPY_TICKS_TRADE
print("Ticks received:",len(ticks))
 
# shut down connection to the MetaTrader 5 terminal

 
# display data on each tick on a new line
print("Display obtained ticks 'as is'")
count = 0
for tick in ticks:
    count+=1
    print(tick)
    if count >= 10:
        break
# Out:
# Ticks received: 0
# Display obtained ticks 'as is'

# %%
mt5.positions_get()
# Out:
# ()

# %%
mt5.positions_total()
# Out:
# 0

# %%
terminal_info=mt5.terminal_info()
if terminal_info!=None:
    terminal_info_dict = mt5.terminal_info()._asdict()

   # convertemos o dicionário num DataFrame e imprimimos
    df=pd.DataFrame(list(terminal_info_dict.items()),columns=['property','value'])
    print("terminal_info() as dataframe:")
    print(df)
# Out:
# terminal_info() as dataframe:
#                  property                                              value
# 0       community_account                                              False
# 1    community_connection                                              False
# 2               connected                                               True
# 3            dlls_allowed                                               True
# 4           trade_allowed                                               True
# 5       tradeapi_disabled                                              False
# 6           email_enabled                                              False
# 7             ftp_enabled                                              False
# 8   notifications_enabled                                              False
# 9                    mqid                                              False
# 10                  build                                               2485
# 11                maxbars                                             100000
# 12               codepage                                               1252
# 13              ping_last                                              12598
# 14      community_balance                                                  0
# 15         retransmission                                          0.0929368
# 16                company                                    CLEAR CTVM S.A.
# 17                   name                              MetaTrader 5 Terminal
# 18               language                                Portuguese (Brazil)
# 19                   path             C:\Program Files\MetaTrader 5 Terminal
# 20              data_path  C:\Users\danie\AppData\Roaming\MetaQuotes\Term...
# 21        commondata_path  C:\Users\danie\AppData\Roaming\MetaQuotes\Term...

# %%
# obtemos todos os símbolos
symbols=mt5.symbols_get()
print('Symbols: ', len(symbols))
count=0
# exibimos os 5 primeiros
for s in symbols:
    if len(s.name)==5:
        print(s.name)
# Out:
# Symbols:  17651
# ABCB4
# AFLT3
# AGRO3
# AHEB3
# AHEB5
# AHEB6
# ALPA3
# ALPA4
# ALUP3
# ALUP4
# AMAR3
# APTI3
# APTI4
# ARZZ3
# AZEV3
# AZEV4
# BAHI3
# BALM3
# BALM4
# BAUH3
# BAZA3
# BAUH4
# BBAS3
# BBDC3
# BBDC4
# BBRK3
# BBSE3
# BDLL3
# BDLL4
# BEEF3
# BEES3
# BEES4
# BGIP3
# BGIP4
# BIOM3
# BMEB3
# BMEB4
# BMIN3
# BMIN4
# BMKS3
# BNBR3
# BOBR3
# BOBR4
# BPAC3
# BPAC5
# BPAR3
# BRAP3
# BRAP4
# BRFS3
# BRGE3
# BRGE5
# BRGE6
# BRGE7
# BRGE8
# BRIV3
# BRIV4
# BRKM3
# BRKM5
# BRKM6
# BRML3
# BRPR3
# BRSR3
# BRSR5
# BRSR6
# BSEV3
# BSLI3
# BSLI4
# BTOW3
# BTTL3
# CALI3
# CALI4
# CAMB3
# CARD3
# CASN3
# CASN4
# CATA3
# CATA4
# CBEE3
# CCPR3
# CCRO3
# CEBR3
# CEBR5
# CEBR6
# CEDO3
# CEDO4
# CEEB3
# CEEB5
# CEEB6
# CEED3
# CEED4
# CEGR3
# CEPE3
# CEPE5
# CEPE6
# CESP3
# CESP5
# CESP6
# CGAS3
# CGAS5
# CGRA3
# CGRA4
# CIEL3
# CLSC3
# CLSC4
# CMIG3
# CMIG4
# CMSA3
# CMSA4
# COCE3
# COCE5
# COCE6
# CORR3
# CORR4
# CPFE3
# CPLE3
# CPLE5
# CPLE6
# CRDE3
# CRIV3
# CRIV4
# CSAB3
# CSAB4
# CSAN3
# CSMG3
# CSNA3
# CSRN3
# CSRN5
# CSRN6
# CTKA3
# CTKA4
# CTNM3
# CTNM4
# CTSA3
# CTSA4
# CTSA8
# CYRE3
# DASA3
# DIRR3
# DOHL3
# DOHL4
# DTCY3
# DTCY4
# DTEX3
# EALT3
# EALT4
# ECOR3
# ECPR3
# ECPR4
# EEEL3
# EEEL4
# EKTR3
# EKTR4
# ELET3
# ELET5
# ELET6
# EMAE3
# EMAE4
# EMBR3
# ENBR3
# ENGI3
# ENGI4
# EQTL3
# ESTR3
# ESTR4
# ETER3
# EUCA3
# EUCA4
# EVEN3
# EZTC3
# FESA3
# FESA4
# FHER3
# FIGE3
# FIGE4
# FLRY3
# FNCN3
# FRAS3
# FRIO3
# GEPA3
# GEPA4
# GFSA3
# GGBR3
# GGBR4
# GOAU3
# GOAU4
# GOLL4
# GPAR3
# GPCP3
# GRND3
# GSHP3
# GUAR3
# HAGA3
# HAGA4
# HBOR3
# HBTS3
# HBTS5
# HBTS6
# HETA3
# HETA4
# HGTX3
# HOOT3
# HOOT4
# HYPE3
# IDVL3
# IDVL4
# IGBR3
# IGTA3
# INEP3
# INEP4
# ITSA3
# ITSA4
# ITUB3
# ITUB4
# JBDU3
# JBDU4
# JBSS3
# JFEN3
# JHSF3
# JOPA3
# JOPA4
# JSLG3
# KEPL3
# KLBN3
# KLBN4
# LAME3
# LAME4
# LCAM3
# LEVE3
# LIGT3
# LINX3
# LIPR3
# LLIS3
# LOGN3
# LPSB3
# LREN3
# LUPA3
# LUXM3
# LUXM4
# MAPT3
# MAPT4
# MDIA3
# MERC3
# MERC4
# MGEL3
# MGEL4
# MGLU3
# MILS3
# MMAQ3
# MMAQ4
# MMXM3
# MNDL3
# MNPR3
# MOAR3
# MRFG3
# MRVE3
# MSPA3
# MSPA4
# MTIG3
# MTIG4
# MTSA3
# MTSA4
# MULT3
# MWET3
# MWET4
# MYPK3
# NEMO3
# NEMO5
# NEMO6
# NORD3
# ODER3
# ODER4
# ODPV3
# OIBR3
# OIBR4
# OSXB3
# PATI3
# PATI4
# PCAR3
# PDGR3
# PEAB3
# PEAB4
# PETR3
# PETR4
# PFRM3
# PINE3
# PINE4
# PLAS3
# PMAM3
# PNVL3
# PNVL4
# POMO3
# POMO4
# POSI3
# PPAR3
# PSEG3
# PSEG4
# PSSA3
# PTBL3
# PTNT3
# PTNT4
# QUAL3
# RADL3
# RANI3
# RANI4
# RAPT3
# RAPT4
# RCSL3
# RCSL4
# RDNI3
# REDE3
# RENT3
# RNEW3
# RNEW4
# ROMI3
# RPAD3
# RPAD5
# RPAD6
# RPMG3
# RSID3
# RSUL3
# RSUL4
# SANB3
# SANB4
# SAPR3
# SAPR4
# SBSP3
# SCAR3
# SGPS3
# SHOW3
# SHUL3
# SHUL4
# SLCE3
# SLED3
# SLED4
# SMTO3
# SNSY3
# SNSY5
# SNSY6
# SOND3
# SOND5
# SOND6
# SPRI3
# SPRI5
# SPRI6
# STBP3
# SULA3
# SULA4
# SUZB3
# TAEE3
# TAEE4
# TCNO3
# TCNO4
# TCSA3
# TECN3
# TEKA3
# TEKA4
# TELB3
# TELB4
# TF473
# TF483
# TF493
# TF503
# TF513
# TF523
# TF533
# TF543
# TF553
# TF563
# TF573
# TF583
# TF593
# TF603
# TF623
# TGMA3
# TIMP3
# TKNO3
# TKNO4
# TOTS3
# TPIS3
# TRIS3
# TRPL3
# TRPL4
# TUPY3
# TXRX3
# TXRX4
# UCAS3
# UGPA3
# UNIP3
# UNIP5
# UNIP6
# USIM3
# USIM5
# USIM6
# VALE3
# VIVR3
# VIVT3
# VIVT4
# VLID3
# VSPT3
# VSPT4
# VULC3
# VVAR3
# WEGE3
# WHRL3
# WHRL4
# SMFT3
# BIDI2
# JPSA3
# INNT3
# B3SA3
# ENEV3
# ANIM3
# SEER3
# ABEV3
# TF993
# CVCB3
# NRTQ3
# NUTR3
# QUSW3
# BGI$D
# BGI$N
# BGI@D
# BGI@N
# CCM$D
# CCM$N
# CCM@D
# CCM@N
# DI1$D
# DI1$N
# DI1@D
# DI1@N
# DOL$D
# DOL$N
# DOL@D
# DOL@N
# ICF$D
# ICF$N
# ICF@D
# ICF@N
# IND$D
# IND$N
# IND@D
# IND@N
# WDO$D
# WDO$N
# WDO@D
# WDO@N
# WIN$D
# WIN$N
# WIN@D
# WIN@N
# BPAN4
# RLOG3
# OFSA3
# ENMT3
# ENMT4
# MEAL3
# MSRO3
# PRIO3
# STKF3
# CRPG3
# CRPG5
# CRPG6
# ATOM3
# TF474
# TF484
# TF494
# TF504
# TF514
# TF524
# TF534
# TF544
# TF554
# TF564
# TF574
# TF584
# TF594
# TF604
# TF624
# TF994
# FRTA3
# TIET3
# TIET4
# BRQB3
# EGIE3
# CNSY3
# CTCA3
# AALR3
# TESA3
# ADHM3
# MOVI3
# PARD3
# RAIL3
# GPCP4
# AZUL4
# WIZS3
# TEND3
# WLMM3
# WLMM4
# CRFB3
# IRBR3
# OMGE3
# TF475
# TF485
# TF495
# TF505
# TF515
# TF525
# TF535
# TF545
# TF555
# TF565
# TF575
# TF585
# TF595
# TF605
# TF625
# TF995
# DMMO3
# CAML3
# STTR3
# IGSN3
# SMLS3
# PRNR3
# BRDT3
# BKBR3
# FLEX3
# GNDI3
# HAPV3
# BIDI4
# PTCA3
# LOGG3
# APER3
# TF643
# TF644
# TF645
# SQIA3
# BBML3
# TF655
# TF665
# TF675
# TF685
# CNTO3
# ENAT3
# GFSA9
# NEOE3
# BIDI3
# YDUQ3
# ALSO3
# BTOW1
# VIVA3
# COGN3
# CEAB3
# TASA3
# TASA4
# BMGB4
# EQPA3
# EQPA5
# EQPA6
# EQPA7
# NTCO3
# LMED3
# MTRE3
# LWSA3
# MDNE3
# ATMP3
# DTCY1
# ALPK3
# TF693
# TF694
# TF703
# TF704
# TF713
# TF714
# TF723
# TF724
# BIDI1
# AMBP3
# PDTC3
# IRBR1
# CVCB1
# SOMA3

# %%
# obtemos símbolos cujos nomes contêm RU
ru_symbols=mt5.symbols_get("*ITS*")
print('len(*RU*): ', len(ru_symbols))
for s in ru_symbols:
    print(s.name)
print()
# Out:
# len(*RU*):  262
# ITSA3
# ITSA4
# ITSAB107
# ITSAB112
# ITSAI125
# ITSAI135
# ITSAI996
# ITSAJ128
# ITSAJ130
# ITSAJ148
# ITSAK135
# ITSAK145
# ITSAN107
# ITSAN112
# ITSAU125
# ITSAU135
# ITSAU996
# ITSAV128
# ITSAV130
# ITSAV148
# ITSAW135
# ITSAW145
# ITSAH115
# ITSAT120
# ITSAH120
# ITSAT115
# ITSAL107
# ITSAX107
# ITSAK930
# ITSAW930
# ITSAC102
# ITSAO102
# ITSAC112
# ITSAO112
# ITSAL100
# ITSAX100
# ITSAH131
# ITSAT131
# ITSAJ114
# ITSAV114
# ITSAI105
# ITSAI108
# ITSAI120
# ITSAU105
# ITSAU108
# ITSAU120
# ITSAJ100
# ITSAJ117
# ITSAJ900
# ITSAV100
# ITSAV117
# ITSAV900
# ITSAH158
# ITSAT158
# ITSAI110
# ITSAU110
# ITSAI115
# ITSAI145
# ITSAI155
# ITSAU115
# ITSAU145
# ITSAU155
# ITSAH141
# ITSAI130
# ITSAT141
# ITSAU130
# ITSAH930
# ITSAT930
# ITSAH106
# ITSAT106
# ITSAK127
# ITSAW127
# ITSAH152
# ITSAT152
# ITSAI97
# ITSAU97
# ITSAL160
# ITSAX160
# ITSAJ111
# ITSAV111
# ITSAL11
# ITSAL123
# ITSAL900
# ITSAL950
# ITSAX11
# ITSAX123
# ITSAX900
# ITSAX950
# ITSAL132
# ITSAX132
# ITSAL477
# ITSAX477
# ITSAA69
# ITSAM69
# ITSAB102
# ITSAB990
# ITSAC107
# ITSAC990
# ITSAN102
# ITSAN990
# ITSAO107
# ITSAO990
# ITSAI132
# ITSAU132
# ITSAK175
# ITSAK178
# ITSAK180
# ITSAW175
# ITSAW178
# ITSAW180
# ITSAI988
# ITSAU988
# ITSAH978
# ITSAT978
# ITSAH109
# ITSAT109
# ITSAD107
# ITSAD840
# ITSAD93
# ITSAP107
# ITSAP840
# ITSAP93
# ITSAE730
# ITSAQ730
# ITSAH638
# ITSAH658
# ITSAH678
# ITSAH698
# ITSAH718
# ITSAH738
# ITSAH748
# ITSAH758
# ITSAH778
# ITSAH798
# ITSAH818
# ITSAH838
# ITSAH858
# ITSAH878
# ITSAH898
# ITSAH918
# ITSAH938
# ITSAH958
# ITSAT638
# ITSAT658
# ITSAT678
# ITSAT698
# ITSAT718
# ITSAT738
# ITSAT748
# ITSAT758
# ITSAT778
# ITSAT798
# ITSAT818
# ITSAT838
# ITSAT858
# ITSAT878
# ITSAT898
# ITSAT918
# ITSAT938
# ITSAT958
# ITSAL824
# ITSAL834
# ITSAL934
# ITSAX824
# ITSAX834
# ITSAX934
# ITSAL102
# ITSAL894
# ITSAL914
# ITSAX102
# ITSAX894
# ITSAX914
# ITSAL842
# ITSAL982
# ITSAX842
# ITSAX982
# ITSAH10
# ITSAH100
# ITSAH110
# ITSAL105
# ITSAL115
# ITSAT10
# ITSAT100
# ITSAT110
# ITSAX105
# ITSAX115
# ITSAH104
# ITSAT104
# ITSAJ113
# ITSAJ934
# ITSAV113
# ITSAV934
# ITSAI140
# ITSAI150
# ITSAI160
# ITSAI856
# ITSAI876
# ITSAI896
# ITSAI916
# ITSAI936
# ITSAI956
# ITSAI976
# ITSAU140
# ITSAU150
# ITSAU160
# ITSAU856
# ITSAU876
# ITSAU896
# ITSAU916
# ITSAU936
# ITSAU956
# ITSAU976
# ITSAL922
# ITSAX922
# ITSAL872
# ITSAX872
# ITSAJ794
# ITSAJ884
# ITSAV794
# ITSAV884
# ITSAH686
# ITSAI686
# ITSAT686
# ITSAU686
# ITSAJ116
# ITSAJ121
# ITSAJ131
# ITSAJ136
# ITSAJ694
# ITSAJ714
# ITSAJ734
# ITSAJ754
# ITSAJ774
# ITSAJ834
# ITSAJ854
# ITSAJ874
# ITSAJ894
# ITSAV116
# ITSAV121
# ITSAV131
# ITSAV136
# ITSAV694
# ITSAV714
# ITSAV734
# ITSAV754
# ITSAV774
# ITSAV834
# ITSAV854
# ITSAV874
# ITSAV894
# ITSAI526
# ITSAI626
# ITSAU526
# ITSAU626
# ITSAK115
# ITSAK830
# ITSAW115
# ITSAW830
# ITSAL110
# ITSAL942
# ITSAX110
# ITSAX942

# %%
# imprimimos as propriedades do símbolo EURJPY
symbol_info=mt5.symbol_info("ITSA4")
if symbol_info!=None:
    # exibimos os dados sobre o terminal tal qual como estão    
    print(symbol_info)
    print("EURJPY: spread =",symbol_info.spread,"  digits =",symbol_info.digits)
    # exibimos as propriedades do símbolo como uma lista
    print("Show symbol_info(\"EURJPY\")._asdict():")
    symbol_info_dict = mt5.symbol_info("ITSA4")._asdict()
    for prop in symbol_info_dict:
        print("  {}={}".format(prop, symbol_info_dict[prop]))
# Out:
# SymbolInfo(custom=False, chart_mode=1, select=True, visible=True, session_deals=8707, session_buy_orders=0, session_sell_orders=0, volume=100, volumehigh=31983841130, volumelow=4500, time=1596454681, digits=2, spread=1, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, ...)
# EURJPY: spread = 1   digits = 2
# Show symbol_info("EURJPY")._asdict():
#   custom=False
#   chart_mode=1
#   select=True
#   visible=True
#   session_deals=8707
#   session_buy_orders=0
#   session_sell_orders=0
#   volume=100
#   volumehigh=31983841130
#   volumelow=4500
#   time=1596454681
#   digits=2
#   spread=1
#   spread_float=True
#   ticks_bookdepth=32
#   trade_calc_mode=32
#   trade_mode=4
#   start_time=0
#   expiration_time=0
#   trade_stops_level=0
#   trade_freeze_level=0
#   trade_exemode=3
#   swap_mode=0
#   swap_rollover3days=3
#   margin_hedged_use_leg=False
#   expiration_mode=2
#   filling_mode=3
#   order_mode=127
#   order_gtc_mode=0
#   option_mode=0
#   option_right=0
#   bid=10.62
#   bidhigh=11.06
#   bidlow=10.76
#   ask=10.63
#   askhigh=11.13
#   asklow=10.77
#   last=10.63
#   lasthigh=10.75
#   lastlow=10.53
#   volume_real=100.0
#   volumehigh_real=31983841130.77977
#   volumelow_real=4500.0
#   option_strike=0.0
#   point=0.01
#   trade_tick_value=0.01
#   trade_tick_value_profit=0.01
#   trade_tick_value_loss=0.01
#   trade_tick_size=0.01
#   trade_contract_size=1.0
#   trade_accrued_interest=0.0
#   trade_face_value=0.0
#   trade_liquidity_rate=0.0
#   volume_min=100.0
#   volume_max=55209772.0
#   volume_step=100.0
#   volume_limit=0.0
#   swap_long=0.0
#   swap_short=0.0
#   margin_initial=0.0
#   margin_maintenance=0.0
#   session_volume=7106100.0
#   session_turnover=0.0
#   session_interest=0.0
#   session_buy_orders_volume=0.0
#   session_sell_orders_volume=0.0
#   session_open=10.73
#   session_close=10.27
#   session_aw=10.65
#   session_price_settlement=0.0
#   session_price_limit_min=0.0
#   session_price_limit_max=0.0
#   margin_hedged=0.0
#   price_change=0.0
#   price_volatility=0.0
#   price_theoretical=0.0
#   price_greeks_delta=0.0
#   price_greeks_theta=0.0
#   price_greeks_gamma=0.0
#   price_greeks_vega=0.0
#   price_greeks_rho=0.0
#   price_greeks_omega=0.0
#   price_sensitivity=0.0
#   basis=
#   category=
#   currency_base=BRL
#   currency_profit=BRL
#   currency_margin=BRL
#   bank=
#   description=ITAUSA      PN      N1
#   exchange=
#   formula=
#   isin=BRITSAACNPR7
#   name=ITSA4
#   page=
#   path=BOVESPA\A VISTA\ITSA4

# %%
# imprimimos o último tick do símbolo GBPUSD
lasttick=mt5.symbol_info_tick("ITSA3")
print(lasttick)
# imprimimos os valores dos campos de tick como uma lista
print("Show symbol_info_tick(\"ITSA3\")._asdict():")
symbol_info_tick_dict = mt5.symbol_info_tick("ITSA3")._asdict()
for prop in symbol_info_tick_dict:
    print("  {}={}".format(prop, symbol_info_tick_dict[prop]))
# Out:
# Tick(time=1596454749, bid=12.07, ask=12.1, last=12.1, volume=300, time_msc=1596454749769, flags=6, volume_real=300.0)
# Show symbol_info_tick("ITSA3")._asdict():
#   time=1596454749
#   bid=12.07
#   ask=12.1
#   last=12.1
#   volume=300
#   time_msc=1596454749769
#   flags=6
#   volume_real=300.0

# %%
# tentamos ativar a exibição do símbolo EURCAD no MarketWatch
selected=mt5.symbol_select("BIDI4",True)
if not selected:
    print("Failed to select BIDI4, error code =",mt5.last_error())
else:
    symbol_info=mt5.symbol_info("BIDI4")
    print(symbol_info)
    print("BIDI4: currency_base =",symbol_info.currency_base,"  currency_profit =",symbol_info.currency_profit,"  currency_margin =",symbol_info.currency_margin)
    print()
 
    # obtemos as propriedades do símbolo como um dicionário
    print("Show symbol_info()._asdict():")
    symbol_info_dict = symbol_info._asdict()
    for prop in symbol_info_dict:
        print("  {}={}".format(prop, symbol_info_dict[prop]))
    print()
 
   # convertemos o dicionário num DataFrame e imprimimos
    df=pd.DataFrame(list(symbol_info_dict.items()),columns=['property','value'])
    print("symbol_info_dict() as dataframe:")
    print(df)
# Out:
# SymbolInfo(custom=False, chart_mode=1, select=True, visible=True, session_deals=2940, session_buy_orders=0, session_sell_orders=0, volume=1000, volumehigh=147455829680, volumelow=100, time=1596454846, digits=2, spread=4, spread_float=True, ticks_bookdepth=32, trade_calc_mode=32, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=3, swap_mode=0, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=2, filling_mode=3, order_mode=127, ...)
# BIDI4: currency_base = BRL   currency_profit = BRL   currency_margin = BRL
#
# Show symbol_info()._asdict():
#   custom=False
#   chart_mode=1
#   select=True
#   visible=True
#   session_deals=2940
#   session_buy_orders=0
#   session_sell_orders=0
#   volume=1000
#   volumehigh=147455829680
#   volumelow=100
#   time=1596454846
#   digits=2
#   spread=4
#   spread_float=True
#   ticks_bookdepth=32
#   trade_calc_mode=32
#   trade_mode=4
#   start_time=0
#   expiration_time=0
#   trade_stops_level=0
#   trade_freeze_level=0
#   trade_exemode=3
#   swap_mode=0
#   swap_rollover3days=3
#   margin_hedged_use_leg=False
#   expiration_mode=2
#   filling_mode=3
#   order_mode=127
#   order_gtc_mode=0
#   option_mode=0
#   option_right=0
#   bid=20.91
#   bidhigh=23.0
#   bidlow=19.61
#   ask=20.95
#   askhigh=20.68
#   asklow=17.19
#   last=20.9
#   lasthigh=21.0
#   lastlow=19.86
#   volume_real=1000.0
#   volumehigh_real=147455829680.66278
#   volumelow_real=100.0
#   option_strike=0.0
#   point=0.01
#   trade_tick_value=0.01
#   trade_tick_value_profit=0.01
#   trade_tick_value_loss=0.01
#   trade_tick_size=0.01
#   trade_contract_size=1.0
#   trade_accrued_interest=0.0
#   trade_face_value=0.0
#   trade_liquidity_rate=0.0
#   volume_min=100.0
#   volume_max=3418426.0
#   volume_step=100.0
#   volume_limit=0.0
#   swap_long=0.0
#   swap_short=0.0
#   margin_initial=0.0
#   margin_maintenance=0.0
#   session_volume=806700.0
#   session_turnover=0.0
#   session_interest=0.0
#   session_buy_orders_volume=0.0
#   session_sell_orders_volume=0.0
#   session_open=20.79
#   session_close=16.75
#   session_aw=20.48
#   session_price_settlement=0.0
#   session_price_limit_min=0.0
#   session_price_limit_max=0.0
#   margin_hedged=0.0
#   price_change=0.0
#   price_volatility=0.0
#   price_theoretical=0.0
#   price_greeks_delta=0.0
#   price_greeks_theta=0.0
#   price_greeks_gamma=0.0
#   price_greeks_vega=0.0
#   price_greeks_rho=0.0
#   price_greeks_omega=0.0
#   price_sensitivity=0.0
#   basis=
#   category=
#   currency_base=BRL
#   currency_profit=BRL
#   currency_margin=BRL
#   bank=
#   description=BANCO INTER PN  EJ  N2
#   exchange=
#   formula=
#   isin=BRBIDIACNPR0
#   name=BIDI4
#   page=
#   path=BOVESPA\A VISTA\BIDI4
#
# symbol_info_dict() as dataframe:
#          property                  value
# 0          custom                  False
# 1      chart_mode                      1
# 2          select                   True
# 3         visible                   True
# 4   session_deals                   2940
# ..            ...                    ...
# 91        formula
# 92           isin           BRBIDIACNPR0
# 93           name                  BIDI4
# 94           page
# 95           path  BOVESPA\A VISTA\BIDI4
#
# [96 rows x 2 columns]

# %%
# definimos o fuso horário como UTC
timezone = pytz.timezone("Etc/UTC")
# criamos o objeto datetime no fuso horário UTC para que não seja aplicado o deslocamento do fuso horário local
utc_from = datetime(2020, 8, 3, tzinfo=timezone)
# recebemos 10 barras de EURUSD H1 a partir de 01/10/2020 no fuso horário UTC
rates = mt5.copy_rates_from("VVAR3", mt5.TIMEFRAME_M5, utc_from, 10)

# exibimos cada elemento de dados recebidos numa nova linha
print("Exibimos os dados recebidos como estão")
for rate in rates:
    print(rate)
# Out:
# Exibimos os dados recebidos como estão
# (1596211500, 19.59, 19.61, 19.49, 19.53, 1019, 1, 578100)
# (1596211800, 19.53, 19.55, 19.48, 19.49, 1005, 1, 477600)
# (1596212100, 19.49, 19.49, 19.28, 19.3, 2377, 1, 1937000)
# (1596212400, 19.29, 19.38, 19.23, 19.37, 1950, 1, 1524900)
# (1596212700, 19.37, 19.42, 19.35, 19.37, 1264, 1, 610500)
# (1596213000, 19.37, 19.4, 19.32, 19.4, 1025, 1, 512800)
# (1596213300, 19.39, 19.41, 19.36, 19.37, 1053, 1, 498900)
# (1596213600, 19.37, 19.41, 19.33, 19.39, 1027, 1, 605100)
# (1596213900, 19.4, 19.53, 19.36, 19.49, 1565, 1, 1480600)
# (1596214200, 19.49, 19.52, 19.3, 19.52, 2267, 1, 5262400)

# %%
# a partir dos dados recebidos criamos o DataFrame
rates_frame = pd.DataFrame(rates)
# convertemos o tempo em segundos no formato datetime
rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
                           
# exibimos dados
print("\nExibimos o dataframe com dados")
print(rates_frame)
# Out:
# Exibimos o dataframe com dados
#                  time   open   high    low  close  tick_volume  spread  real_volume
# 0 2020-07-31 16:05:00  19.59  19.61  19.49  19.53         1019       1       578100
# 1 2020-07-31 16:10:00  19.53  19.55  19.48  19.49         1005       1       477600
# 2 2020-07-31 16:15:00  19.49  19.49  19.28  19.30         2377       1      1937000
# 3 2020-07-31 16:20:00  19.29  19.38  19.23  19.37         1950       1      1524900
# 4 2020-07-31 16:25:00  19.37  19.42  19.35  19.37         1264       1       610500
# 5 2020-07-31 16:30:00  19.37  19.40  19.32  19.40         1025       1       512800
# 6 2020-07-31 16:35:00  19.39  19.41  19.36  19.37         1053       1       498900
# 7 2020-07-31 16:40:00  19.37  19.41  19.33  19.39         1027       1       605100
# 8 2020-07-31 16:45:00  19.40  19.53  19.36  19.49         1565       1      1480600
# 9 2020-07-31 16:50:00  19.49  19.52  19.30  19.52         2267       1      5262400

# %% [markdown]
# ## Copy rates from pos

# %%
# solicitamos 10 barras de GBPUSD D1 do dia atual
rates = mt5.copy_rates_from_pos("BBDC4", mt5.TIMEFRAME_M1, 0, 10)
  
# exibimos cada elemento de dados recebidos numa nova linha
print("Exibimos os dados recebidos como estão")
for rate in rates:
    print(rate)
# Out:
# Exibimos os dados recebidos como estão
# (1596466380, 22.59, 22.62, 22.58, 22.6, 352, 1, 250700)
# (1596466440, 22.6, 22.61, 22.59, 22.61, 136, 1, 54400)
# (1596466500, 22.61, 22.64, 22.61, 22.63, 303, 1, 140100)
# (1596466560, 22.63, 22.64, 22.63, 22.63, 150, 1, 55300)
# (1596466620, 22.63, 22.64, 22.6, 22.62, 248, 1, 173000)
# (1596466680, 22.62, 22.63, 22.61, 22.61, 142, 1, 57100)
# (1596466740, 22.61, 22.63, 22.61, 22.61, 158, 1, 57300)
# (1596466800, 22.61, 22.61, 22.59, 22.59, 175, 1, 115000)
# (1596466860, 22.59, 22.6, 22.57, 22.57, 180, 1, 81000)
# (1596466920, 22.57, 22.59, 22.56, 22.59, 184, 1, 86700)

# %%
# a partir dos dados recebidos criamos o DataFrame
rates_frame = pd.DataFrame(rates)
# convertemos o tempo em segundos no formato datetime
rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
rates_frame
# Out:
#                  time   open   high    low  close  tick_volume  spread  real_volume
# 0 2020-08-03 11:41:00  22.29  22.32  22.29  22.32           74       1        23800
# 1 2020-08-03 11:42:00  22.31  22.32  22.30  22.31           92       1        19100
# 2 2020-08-03 11:43:00  22.31  22.33  22.28  22.28          124       1        50200
# 3 2020-08-03 11:44:00  22.28  22.34  22.27  22.33          151       1        67900
# 4 2020-08-03 11:45:00  22.34  22.35  22.31  22.31          157       1        47200
# 5 2020-08-03 11:46:00  22.32  22.32  22.28  22.29           61       1        18300
# 6 2020-08-03 11:47:00  22.30  22.30  22.28  22.29           45       1        17800
# 7 2020-08-03 11:48:00  22.30  22.33  22.29  22.33           85       1        30600
# 8 2020-08-03 11:49:00  22.32  22.36  22.32  22.34           73       1        25700
# 9 2020-08-03 11:50:00  22.34  22.35  22.34  22.34           36       1        11200

# %% [markdown]
# ## copy_rates_range

# %%
utc_from = datetime(2020, 1, 10, tzinfo=timezone)
utc_to = datetime(2020, 1, 11, hour = 13, tzinfo=timezone)
# obtemos as barras com USDJPY M5 no intervalo 2020.01.10 00:00 - 2020.01.11 13:00 no fuso horário UTC
rates = mt5.copy_rates_range("BPAC11", mt5.TIMEFRAME_M5, utc_from, utc_to)
 
# criamos a partir dos dados obtidos DataFrame
rates_frame = pd.DataFrame(rates)
# convertemos o tempo em segundos no formato datetime
rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
 
# exibimos dados
print("\nExibimos o dataframe com dados")
print(rates_frame.head(10))
# Out:
# Exibimos o dataframe com dados
#                  time   open   high    low  close  tick_volume  spread  real_volume
# 0 2020-01-10 10:00:00  76.00  78.20  76.00  77.20          261       1        56900
# 1 2020-01-10 10:05:00  77.19  77.20  76.60  76.76          176       1        47500
# 2 2020-01-10 10:10:00  76.76  76.78  76.00  76.25          174       1        43600
# 3 2020-01-10 10:15:00  76.27  76.35  75.80  75.90           99       1        77300
# 4 2020-01-10 10:20:00  75.90  75.90  75.62  75.90           51       1        10400
# 5 2020-01-10 10:25:00  75.90  75.90  75.78  75.85           42       1        14700
# 6 2020-01-10 10:30:00  75.85  76.14  75.83  76.14          136       1        41600
# 7 2020-01-10 10:35:00  76.14  76.40  76.14  76.37          110       1        21700
# 8 2020-01-10 10:40:00  76.40  76.40  76.26  76.30           79       1        17900
# 9 2020-01-10 10:45:00  76.30  76.40  76.20  76.34           77       1        26500

# %% [markdown]
# ## copy_ticks_from

# %%
# definimos o fuso horário como UTC
timezone = pytz.timezone("Etc/UTC")
# criamos o objeto datetime no fuso horário UTC para que não seja aplicado o deslocamento do fuso horário localutc_from = datetime(2020, 1, 10, tzinfo=timezone)
# solicitamos 100 000 ticks de EURUSD a partir de 04/01/2019 no fuso horário UTC
ticks = mt5.copy_ticks_from("ITSA4", utc_from, 500, mt5.COPY_TICKS_ALL)

# a partir dos dados recebidos criamos o DataFrame
ticks_frame = pd.DataFrame(ticks)
# convertemos o tempo em segundos no formato datetime

ticks_frame['time']=pd.to_datetime(ticks_frame['time'], unit='s')
 
# exibimos dados
print("\nExibimos o dataframe com ticks")
print(ticks_frame.head(20))
# Out:
# Exibimos o dataframe com ticks
#                   time    bid    ask   last  volume       time_msc  flags  volume_real
# 0  2020-08-03 09:37:55  10.65  10.73   0.00       0  1596447475538      6          0.0
# 1  2020-08-03 09:40:55  10.65  10.73   0.00       0  1596447655442      6          0.0
# 2  2020-08-03 09:45:00  10.65  10.73   0.00       0  1596447900056      6          0.0
# 3  2020-08-03 09:45:00  10.65  10.72   0.00       0  1596447900210      4          0.0
# 4  2020-08-03 09:45:00  10.71  10.72   0.00       0  1596447900256      2          0.0
# 5  2020-08-03 09:45:00  13.00  10.72   0.00       0  1596447900986      2          0.0
# 6  2020-08-03 09:45:11  13.00  10.70   0.00       0  1596447911081      4          0.0
# 7  2020-08-03 09:45:15  13.00  10.65   0.00       0  1596447915429      4          0.0
# 8  2020-08-03 09:45:26  13.00  10.60   0.00       0  1596447926516      4          0.0
# 9  2020-08-03 09:46:00  13.00  10.60   0.00       0  1596447960528      2          0.0
# 10 2020-08-03 09:46:27  13.00  10.60   0.00       0  1596447987888      4          0.0
# 11 2020-08-03 09:46:45  13.00  10.00   0.00       0  1596448005767      4          0.0
# 12 2020-08-03 10:13:23  13.00  10.00  10.73     100  1596449603562     56        100.0
# 13 2020-08-03 10:13:23  13.00  10.00  10.73     600  1596449603562     56        600.0
# 14 2020-08-03 10:13:23  13.00  10.00  10.73     500  1596449603562     56        500.0
# 15 2020-08-03 10:13:23  13.00  10.00  10.73  123800  1596449603562     56     123800.0
# 16 2020-08-03 10:13:23  13.00  10.00  10.73     300  1596449603562     56        300.0
# 17 2020-08-03 10:13:23  13.00  10.00  10.73     800  1596449603562     56        800.0
# 18 2020-08-03 10:13:23  13.00  10.00  10.73    4400  1596449603562     56       4400.0
# 19 2020-08-03 10:13:23  13.00  10.00  10.73     300  1596449603562     56        300.0

# %% [markdown]
# ## copy_ticks_range

# %%
# definimos o fuso horário como UTC
timezone = pytz.timezone("Etc/UTC")
# criamos o objeto datatime no fuso horário UTC para que não seja aplicado o deslocamento do fuso horário local
utc_from = datetime(2019, 1, 1, tzinfo=timezone)
utc_to = datetime(2020, 1, 1, tzinfo=timezone)
# solicitamos ticks de AUDUSD no intervalo de 11.01.2020 - 11.01.2020
ticks = mt5.copy_ticks_range("ITSA4", utc_from, utc_to, mt5.COPY_TICKS_ALL )
print("Ticks recebidos:",len(ticks))

# a partir dos dados recebidos criamos o DataFrame
ticks_frame = pd.DataFrame(ticks)
# convertemos o tempo em segundos no formato datetime
ticks_frame['time']=pd.to_datetime(ticks_frame['time'], unit='s')
 
# exibimos dados
print("\nExibimos o dataframe com ticks")
print(ticks_frame.head(10))
# Out:
# Ticks recebidos: 0
#
# Exibimos o dataframe com ticks
# Empty DataFrame
# Columns: [time, bid, ask, last, volume, time_msc, flags, volume_real]
# Index: []
