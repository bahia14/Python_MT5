# %%
import MetaTrader5 as mt5
from datetime import datetime
import pandas as pd
import pytz

def baixa_cotacao(ticker):
    timezone = pytz.timezone("Etc/UTC")
    utc_from = datetime(2020, 7, 1, tzinfo=timezone)
    rates = mt5.copy_rates_from(ticker, mt5.TIMEFRAME_M5, utc_from, 3000)
    dados = pd.DataFrame(rates)
    dados['time']=pd.to_datetime(dados['time'], unit='s')
    dados = dados.set_index('time')
    dados = dados[['close', 'real_volume']]
    return dados

def concatenate(empresas):
    #downloading data
    dic = {}
    for i in empresas:
        try:
            dic[i] = baixa_cotacao(i)
        except:
            print(f'algum erro com: {i}')
    #concatenating        
    conc = False
    for k,v in dic.items():
        if not conc:
            data = dic[k]
            conc = True
        else:
            data = pd.concat([data,dic[k]],axis=1,join='inner')
    #changing columns names    
    colm = [] 
    for i in empresas:
        colm.append(['Close '+i])
        colm.append(['Volume '+i])

    flatList = [ item for elem in colm for item in elem]
    data.columns = flatList
    
    return data

# %%
mt5.initialize()
# Out:
# True

# %%
empresas = ['ITSA4','ITSA3','IBOV','BBAS3','BIDI4','ITUB3','ITUB4']

# %%
dados = concatenate(empresas)

# %%
dados.head()
# Out:
#                      Close ITSA4  Volume ITSA4  Close ITSA3  Volume ITSA3  \
# time
# 2019-12-20 14:40:00        13.42         52900        13.47           500
# 2019-12-20 14:45:00        13.41         21900        13.49          1300
# 2019-12-20 14:50:00        13.42        135600        13.51           900
# 2019-12-20 15:00:00        13.40         18400        13.49           600
# 2019-12-20 15:05:00        13.41         16500        13.49           500
#
#                      Close IBOV  Volume IBOV  Close BBAS3  Volume BBAS3  \
# time
# 2019-12-20 14:40:00    114894.0    145810380        49.94         39500
# 2019-12-20 14:45:00    114950.0    110806270        50.04         88000
# 2019-12-20 14:50:00    115026.0    145016620        50.05         74600
# 2019-12-20 15:00:00    114929.0    253162856        50.05        103500
# 2019-12-20 15:05:00    114909.0     66152725        50.00         43400
#
# ...

# %%
dados.to_excel('cotacoes.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-bcd7a5e89b56> in <module>
# ----> 1 dados.to_excel('cotacoes.xlsx')
#
# c:\users\danie\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# c:\users\danie\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     724             need_save = False
#     725         else:
# ...

# %%
mt5.shutdown()
# Out:
# True

# %%
qu = ['WIN$', 'DOL$']

# %%
dados
# Out:
#                      Close WIN$  Volume WIN$  Close WIN@  Volume WIN@  \
# time
# 2020-05-21 10:45:00     82780.0       145738     82780.0       145738
# 2020-05-21 10:50:00     82700.0       118176     82700.0       118176
# 2020-05-21 10:55:00     82710.0       133841     82710.0       133841
# 2020-05-21 11:00:00     82710.0       105676     82710.0       105676
# 2020-05-21 11:05:00     82835.0        96694     82835.0        96694
# ...                         ...          ...         ...          ...
# 2020-06-30 17:30:00     95170.0        47030     95170.0        47030
# 2020-06-30 17:35:00     95175.0        33024     95175.0        33024
# 2020-06-30 17:40:00     95170.0        21446     95170.0        21446
# 2020-06-30 17:45:00     95135.0        25045     95135.0        25045
# 2020-06-30 17:50:00     95100.0        33838     95100.0        33838
#
#                      Close WIN$D  Volume WIN$D  Close WIN$N  Volume WIN$N  \
# time
# ...

# %%
with pd.ExcelWriter('dados_win_dol.xlsx', mode='a') as writer:
    dados.to_excel(writer, sheet_name='5m 3000 validacao', index=False)

# %%
dados.to_excel('dados_win_dol.xlsx')

# %% [markdown]
# ## download with all features

# %%
import MetaTrader5 as mt5
from datetime import datetime
import pandas as pd
import pytz

def baixa_cotacao(ticker):
    timezone = pytz.timezone("Etc/UTC")
    utc_from = datetime(2020, 5, 1, tzinfo=timezone)
    rates = mt5.copy_rates_from(ticker, mt5.TIMEFRAME_M5, utc_from, 90000)
    dados = pd.DataFrame(rates)
    dados['time']=pd.to_datetime(dados['time'], unit='s')
    dados = dados.set_index('time')
    dados = dados[['open', 'high', 'low', 'close', 'real_volume']]
    return dados

def concatenate(empresas):
    #downloading data
    dic = {}
    for i in empresas:
        try:
            dic[i] = baixa_cotacao(i)
        except:
            print(f'algum erro com: {i}')
    #concatenating        
    conc = False
    for k,v in dic.items():
        if not conc:
            data = dic[k]
            conc = True
        else:
            data = pd.concat([data,dic[k]],axis=1,join='inner')
    #changing columns names    
    colm = [] 
    for i in empresas:
        colm.append(['open '+i])
        colm.append(['high '+i])
        colm.append(['low '+i])
        colm.append(['close '+i])
        colm.append(['volume'+i])

    flatList = [ item for elem in colm for item in elem]
    data.columns = flatList
    
    return data

# %%
qu = ['WIN$', 'DOL$']

# %%
dados = concatenate(qu)

# %%
dados
# Out:
#                      open WIN$  high WIN$  low WIN$  close WIN$  volumeWIN$  \
# time
# 2016-12-21 13:25:00    70695.0    70852.0   70689.0     70815.0        8192
# 2016-12-21 13:30:00    70815.0    70815.0   70477.0     70544.0       22378
# 2016-12-21 13:35:00    70538.0    70664.0   70501.0     70622.0        8733
# 2016-12-21 13:40:00    70628.0    70664.0   70520.0     70556.0        6383
# 2016-12-21 13:45:00    70556.0    70652.0   70532.0     70592.0        5014
# ...                        ...        ...       ...         ...         ...
# 2020-04-30 17:30:00    80265.0    80310.0   80160.0     80275.0       50402
# 2020-04-30 17:35:00    80270.0    80345.0   80205.0     80315.0       40176
# 2020-04-30 17:40:00    80310.0    80340.0   80165.0     80180.0       35605
# 2020-04-30 17:45:00    80180.0    80245.0   80095.0     80140.0       37704
# 2020-04-30 17:50:00    80140.0    80320.0   79955.0     80100.0       44130
#
# ...

# %%
baixa_cotacao('WIN$').columns
# Out:
# Index(['open', 'high', 'low', 'close', 'tick_volume', 'spread', 'real_volume'], dtype='object')

# %%
dados.to_excel('cotacaotreino_win_dol.xlsx')

# %%
import MetaTrader5 as mt5
from datetime import datetime
import pandas as pd
import pytz

def baixa_cotacao(ticker):
    timezone = pytz.timezone("Etc/UTC")
    utc_from = datetime(2020, 7, 9, tzinfo=timezone)
    rates = mt5.copy_rates_from(ticker, mt5.TIMEFRAME_M5, utc_from, 3000)
    dados = pd.DataFrame(rates)
    dados['time']=pd.to_datetime(dados['time'], unit='s')
    dados = dados.set_index('time')
    dados = dados[['open', 'high', 'low', 'close', 'real_volume']]
    return dados

def concatenate(empresas):
    #downloading data
    dic = {}
    for i in empresas:
        try:
            dic[i] = baixa_cotacao(i)
        except:
            print(f'algum erro com: {i}')
    #concatenating        
    conc = False
    for k,v in dic.items():
        if not conc:
            data = dic[k]
            conc = True
        else:
            data = pd.concat([data,dic[k]],axis=1,join='inner')
    #changing columns names    
    colm = [] 
    for i in empresas:
        colm.append(['open '+i])
        colm.append(['high '+i])
        colm.append(['low '+i])
        colm.append(['close '+i])
        colm.append(['volume'+i])

    flatList = [ item for elem in colm for item in elem]
    data.columns = flatList
    
    return data

# %%
dados = concatenate(qu)

# %%
dados
# Out:
#                      open WIN$  high WIN$  low WIN$  close WIN$  volumeWIN$  \
# time
# 2020-05-29 10:50:00    86975.0    87080.0   86865.0     86890.0      113069
# 2020-05-29 10:55:00    86890.0    86915.0   86545.0     86605.0      149695
# 2020-05-29 11:00:00    86600.0    86705.0   86505.0     86565.0      109485
# 2020-05-29 11:05:00    86565.0    86665.0   86275.0     86360.0      147821
# 2020-05-29 11:10:00    86360.0    86415.0   86235.0     86390.0      122927
# ...                        ...        ...       ...         ...         ...
# 2020-07-08 17:30:00   100010.0   100090.0  100005.0    100055.0       33064
# 2020-07-08 17:35:00   100050.0   100060.0  100020.0    100025.0       20298
# 2020-07-08 17:40:00   100020.0   100065.0  100015.0    100050.0       24595
# 2020-07-08 17:45:00   100050.0   100060.0  100000.0    100030.0       26754
# 2020-07-08 17:50:00   100030.0   100150.0  100005.0    100150.0       34485
#
# ...

# %%
with pd.ExcelWriter('cotacaotreino_win_dol.xlsx', mode='a') as writer:
    dados.to_excel(writer, sheet_name='validacao', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-103-ab1f9c870999> in <module>
#       1 with pd.ExcelWriter('cotacaotreino_win_dol.xlsx', mode='a') as writer:
# ----> 2     dados.to_excel(writer, sheet_name='validacao', index=False)
#
# c:\users\danie\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in __exit__(self, exc_type, exc_value, traceback)
#     775
#     776     def __exit__(self, exc_type, exc_value, traceback):
# --> 777         self.close()
#     778
#     779     def close(self):
#
# c:\users\danie\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in close(self)
#     779     def close(self):
#     780         """synonym for save, to make it more file-like"""
# --> 781         return self.save()
#     782
#     783
#
# ...

# %%
dados.to_excel('cotacaovalidacao_win_dol.xlsx')
